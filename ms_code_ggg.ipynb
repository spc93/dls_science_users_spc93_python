# %%
"""
Plot multiple scattering using Dans_Diffraction

install Dans_Diffraction using:
$ pip install dans_diffraction

or download using:
$ git clone https://github.com/DanPorter/Dans_Diffraction.git

"""

import sys, os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
sys.path.insert(0, '/dls_sw/i16/software/python/userscripts/i16user/Dans_Diffraction') 

import Dans_Diffraction as dif

#cif_file=r"C:\Users\dgpor\OneDrive - Diamond Light Source Ltd\CIF_Files\Na0.8CoO2_P63mmc.cif"
cif_file = '/home/spc93/spc_cifs/ggg sawada.cif'


xtl = dif.Crystal(cif_file)

xtl.Plot.plot_multiple_scattering([0,0,6], [1,0,0], energy_range=[7.2, 7.3])

#xtl.Plot.plot_ms_azimuth([0, 0, 6], 7.243, [1, 0, 0], peak_width=0.1)
#plt.show()
# Out:
# MS Reflections: 13036
# 1 of 60
# /dls_sw/i16/software/python/userscripts/i16user/Dans_Diffraction/Dans_Diffraction/multiple_scattering.py:375: RuntimeWarning: invalid value encountered in arcsin
#   ((ko * np.sin(-brag1 * np.pi / 180.0)) + (realvecthkl[:, 2])) / ko) * 180.0 / np.pi) * np.pi / 180.0)
# /dls_sw/i16/software/python/userscripts/i16user/Dans_Diffraction/Dans_Diffraction/multiple_scattering.py:386: RuntimeWarning: invalid value encountered in sqrt
#   np.divide((np.square(orighk) - np.square(rhk) + np.square(rewl)), 2.0 * orighk)))
# 2 of 60
# 3 of 60
# 4 of 60
# 5 of 60
# 6 of 60
# 7 of 60
# 8 of 60
# 9 of 60
# 10 of 60
# 11 of 60
# 12 of 60
# 13 of 60
# 14 of 60
# 15 of 60
# 16 of 60
# 17 of 60
# 18 of 60
# 19 of 60
# 20 of 60
# 21 of 60
# 22 of 60
# 23 of 60
# 24 of 60
# 25 of 60
# 26 of 60
# 27 of 60
# 28 of 60
# 29 of 60
# 30 of 60
# 31 of 60
# 32 of 60
# 33 of 60
# 34 of 60
# 35 of 60
# 36 of 60
# 37 of 60
# 38 of 60
# 39 of 60
# 40 of 60
# 41 of 60
# 42 of 60
# 43 of 60
# 44 of 60
# 45 of 60
# 46 of 60
# 47 of 60
# 48 of 60
# 49 of 60
# 50 of 60
# 51 of 60
# 52 of 60
# 53 of 60
# 54 of 60
# 55 of 60
# 56 of 60
# 57 of 60
# 58 of 60
# 59 of 60
# 60 of 60
# <img src="data:image/png;base64,..." width="1440">

# %%
xtl.Plot.plot_ms_azimuth([0, 0, 6], 7.243, [1, 0, 0], peak_width=0.1)
# Out:
# MS Reflections: 12796
# 1 of 3
# 2 of 3
# 3 of 3
# <img src="data:image/png;base64,..." width="719.9999843944206">
