# %%
#%run TensorScatteringClass

# %%
import TensorScatteringClass as ten
import numpy as np
# %matplotlib inline


E_UM5 = 3.552

t=ten.TensorScatteringClass(CIFfile='/home/spc93/spc_cifs/U2N3.cif', Site='U2');
t.PlotIntensityInPolarizationChannels('E1E1', lam=12.4/E_UM5, hkl=np.array([0, 0, 2]), hkln=np.array([1,0,0]), K=2, Time=1, Parity=1, mk=None, lk=None, sk=None, sigmapi='sigma')
t.print_tensors()

# 003 U1: forbidden & tensor forbidden
# 002 U1: allowed
# 003 U2: forbidden & tensor forbidden




#E1E2 etc
#t.PlotIntensityInPolarizationChannels('E1E2', lam=12.4/E_UM5, hkl=np.array(ref), hkln=np.array([1,0,0]), K=3, Time=1, Parity=-1, mk=None, lk=None, sk=None, sigmapi='sigma')
#t.print_tensors()
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/U2N3.cif
#                      Lattice:  10.678 10.678 10.678 90.00 90.00 90.00
#                    All sites:  U1, U2, N1
#                Site selected:  U2
#                  Site vector:  -0.018 0.000 0.250
#        No. of spacegroup ops:  48
#       No. of sym ops at site:  2
#  No. of equiv. sites in cell:  24
#    No. of pg ops for crystal:  24
#
# Tensor properties
#
#              Required parity:  Even
#           Required time sym.:  Even
#                          hkl:  [0.0, 0.0, 2.0]
#                 Site allowed:  Yes
#    Structure factor for site:  7.80+-0.00i
#           Spacegroup allowed:  Yes
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
#               Glide or screw:  True
# Tensor components
#
#          Crystal (spherical):  [ 0.+0.j  0.+0.j -0.+0.j  0.+0.j  0.-0.j]
#             Atom (spherical):  [0.561+0.j    0.   +0.686j 1.   +0.j    0.   +0.686j 0.561+0.j   ]
#   Struct. factor (spherical):  [ 0.548-0.j -0.   +0.j  1.   -0.j  0.   +0.j  0.548+0.j]
#
# Crystal (Cartesian):
#
# [[-0.+0.j -0.+0.j  0.+0.j]
#  [-0.+0.j -0.+0.j -0.+0.j]
#  [ 0.+0.j -0.+0.j -0.+0.j]]
#
# Atom (Cartesian):
#
# [[ 0.069+0.j  0.   +0.j  0.   +0.j]
#  [ 0.   +0.j -0.436+0.j -0.309+0.j]
#  [ 0.   +0.j -0.309+0.j  0.367+0.j]]
#
# Struct. factor (Cartesian):
#
# [[-0.146+0.j -0.   +0.j  0.   -0.j]
#  [-0.   +0.j  1.   +0.j  0.   -0.j]
#  [ 0.   -0.j  0.   -0.j -0.854+0.j]]

# %%
#### tests - delete

import TensorScatteringClass as ten
import numpy as np

#CIFfile='/home/spc93/Dropbox/spc_cifs/ZnO Kisi et al icsd_67454.cif'; #ZnO E1E2
#CIFfile='/media/sf_Dropbox/spc_cifs/ZnO Kisi et al icsd_67454.cif'; TimeEven=True #add time symmetry (later)
#hkl=array([1, 1, 5]); hkln=array([0,0,1]); lam=12.4/9.659 ; sitevec=array([1./3, 2./3, 0.]); mpol='E1E2';K=3; time=+1;parity=-1; ##d_an=d_PG008=3.355/4; pol_theta=arcsin(lam/2/d_an);




t=ten.TensorScatteringClass(CIFfile='ZnO Kisi et al icsd_67454.cif', Site='Zn1')
#t=ten.TensorScatteringClass(CIFfile='/media/sf_Dropbox/spc_cifs/GaFeO3_icsd_55840.cif'); print t
#t=ten.TensorScatteringClass(CIFfile='/media/sf_Dropbox/spc_cifs/GaFeO3_icsd_55840.cif', Site='Fe2'); print t
#t.equiv_sites(t.sglist, t.sitevec)


### check sum of phases for GaFeO3 (same in new version as old)

#print(t.TensorCalc(calctype='tensor', K=2, hkl=np.array([0,0,1]))) #### error: no calctype keyword

#print(t.TensorCalc(K=2, hkl=np.array([0,0,1])))

t.PlotIntensityInPolarizationChannels('E1E2', lam=12.4/9.659, hkl=np.array([1,1,5]), hkln=np.array([1,0,0]), K=3, Time=1, Parity=-1, mk=None, sk=None, sigmapi='sigma')

t.print_tensors()
# Out:
# Crystal properties
#
#                     CIF file:  ZnO Kisi et al icsd_67454.cif
#                      Lattice:  3.250 3.250 5.207 90.00 90.00 120.00
#                    All sites:  Zn1, O1
#                Site selected:  Zn1
#                  Site vector:  0.333 0.667 0.000
#        No. of spacegroup ops:  12
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  2
#    No. of pg ops for crystal:  12
#
# Tensor properties
#
#              Required parity:  Odd
#           Required time sym.:  Even
#                          hkl:  [1.0, 1.0, 5.0]
#                 Site allowed:  No
#    Structure factor for site:  0.00+0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
# ('\nTensor components\n', '\n         Crystal (spherical):  ', array([ 0.-0.j, -0.+0.j, -0.+0.j,  1.+0.j,  0.+0.j, -0.-0.j,  0.-0.j]), '\n            Atom (spherical):  ', array([ 1.   +0.j,  0.   +0.j, -0.   -0.j,  0.739+0.j,  0.   -0.j,
#         0.   -0.j, -1.   -0.j]), '\n  Struct. factor (spherical):  ', array([ 1.-0.j, -0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j, -1.-0.j]), '\n\nCrystal (Cartesian):\n\n', array([[[ 0.   +0.j,  0.   +0.j, -2.515+0.j],
#         [ 0.   +0.j, -0.   +0.j, -0.   +0.j],
#         [-2.515+0.j, -0.   +0.j, -0.   +0.j]],
#
#        [[ 0.   +0.j,  0.   +0.j, -0.   +0.j],
#         [ 0.   +0.j, -0.   -0.j, -2.515+0.j],
#         [-0.   +0.j, -2.515+0.j, -0.   +0.j]],
#
#        [[-2.515+0.j, -0.   +0.j, -0.   +0.j],
#         [-0.   +0.j, -2.515+0.j, -0.   +0.j],
#         [-0.   +0.j, -0.   +0.j,  5.031+0.j]]]), '\n\nAtom (Cartesian):\n\n', array([[[ 3.807+0.j,  0.   +0.j, -1.258+0.j],
#         [ 0.   +0.j, -3.807-0.j, -0.   -0.j],
#         [-1.258+0.j, -0.   -0.j, -0.   +0.j]],
#
#        [[ 0.   +0.j, -3.807-0.j, -0.   -0.j],
#         [-3.807-0.j, -0.   -0.j, -1.258-0.j],
#         [-0.   -0.j, -1.258-0.j, -0.   -0.j]],
#
#        [[-1.258+0.j, -0.   -0.j, -0.   +0.j],
#         [-0.   -0.j, -1.258-0.j, -0.   -0.j],
#         [-0.   +0.j, -0.   -0.j,  2.515+0.j]]]), '\n\nStruct. factor (Cartesian):\n\n', array([[[-1.-0.j, -0.-0.j, -0.-0.j],
#         [-0.-0.j,  1.-0.j,  0.+0.j],
#         [-0.-0.j,  0.+0.j, -0.+0.j]],
#
#        [[-0.-0.j,  1.-0.j,  0.+0.j],
#         [ 1.+0.j, -0.-0.j,  0.+0.j],
#         [ 0.+0.j,  0.+0.j,  0.+0.j]],
#
#        [[-0.-0.j,  0.+0.j, -0.+0.j],
#         [ 0.+0.j,  0.+0.j,  0.+0.j],
#         [-0.+0.j,  0.+0.j, -0.-0.j]]]), '\n')

# %%
import TensorScatteringClass as ten

t=ten.TensorScatteringClass(CIFfile='/home/spc93/spc_cifs/nchem.2848-s6.cif', Site='Cu1');

#t.PlotIntensityInPolarizationChannels('E1E1', lam=1, hkl=np.array([0,0,1]), hkln=np.array([1,0,0]), K=2, Time=1, Parity=1, mk=None, nk=None, sk=None, sigmapi='sigma') #error no nk keyword
t.PlotIntensityInPolarizationChannels('E1E1', lam=1, hkl=np.array([0,0,1]), hkln=np.array([1,0,0]), K=2, Time=1, Parity=1, mk=None, sk=None, sigmapi='sigma')

t.print_tensors()
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/nchem.2848-s6.cif
#                      Lattice:  10.257 4.678 11.221 90.00 92.81 90.00
#                    All sites:  C1, H1A, H1B, H1C, C2, C3, H3, C4, C5, H5A, H5B, H5C, O1, O2, Cu1
#                Site selected:  Cu1
#                  Site vector:  0.500 0.500 0.500
#        No. of spacegroup ops:  4
#       No. of sym ops at site:  2
#  No. of equiv. sites in cell:  2
#    No. of pg ops for crystal:  4
#
# Tensor properties
#
#              Required parity:  Even
#           Required time sym.:  Even
#                          hkl:  [0.0, 0.0, 1.0]
#                 Site allowed:  No
#    Structure factor for site:  0.00+0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
# ('\nTensor components\n', '\n         Crystal (spherical):  ', array([ 1.   -0.j,  0.882+0.j,  0.504+0.j, -0.882-0.j,  1.   +0.j]), '\n            Atom (spherical):  ', array([ 1.   +0.j   ,  0.753-0.143j,  0.279-0.25j , -0.224+0.733j,
#         0.108-0.994j]), '\n  Struct. factor (spherical):  ', array([ 1.   -0.j,  0.593+0.j,  0.   -0.j,  0.593+0.j, -1.   -0.j]), '\n\nCrystal (Cartesian):\n\n', array([[ 2.556+0.j,  0.   +0.j,  2.837+0.j],
#        [ 0.   +0.j, -3.879+0.j,  0.   +0.j],
#        [ 2.837+0.j,  0.   +0.j,  1.323+0.j]]), '\n\nAtom (Cartesian):\n\n', array([[ 1.278+0.j, -1.443+0.j,  1.418+0.j],
#        [-1.443+0.j, -1.94 +0.j, -0.856+0.j],
#        [ 1.418+0.j, -0.856+0.j,  0.662+0.j]]), '\n\nStruct. factor (Cartesian):\n\n', array([[0.   +0.j, 1.   +0.j, 0.   +0.j],
#        [1.   +0.j, 0.   +0.j, 0.593+0.j],
#        [0.   +0.j, 0.593+0.j, 0.   +0.j]]), '\n')

# %%
# %run TensorScatteringClass
# Out:
# === Trying to load crystal data from CIF file...
#
# Crystal properties
#
#                     CIF file:  ZnO Kisi et al icsd_67454.cif
#                      Lattice:  3.250 3.250 5.207 90.00 90.00 120.00
#                    All sites:  Zn1, O1
#                Site selected:  Zn1
#                  Site vector:  0.333 0.667 0.000
#        No. of spacegroup ops:  12
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  2
#    No. of pg ops for crystal:  12
#
# Tensor properties
#
#              Required parity:  Odd
#           Required time sym.:  Even
#                          hkl:  [1.0, 1.0, 5.0]
#                 Site allowed:  No
#    Structure factor for site:  0.00+0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
# ('\nTensor components\n', '\n         Crystal (spherical):  ', array([ 0.-0.j, -0.+0.j, -0.+0.j,  1.+0.j,  0.+0.j, -0.-0.j, -0.-0.j]), '\n            Atom (spherical):  ', array([ 1.   +0.j,  0.   +0.j, -0.   -0.j,  0.225+0.j,  0.   -0.j,
#         0.   -0.j, -1.   -0.j]), '\n  Struct. factor (spherical):  ', array([ 1.-0.j,  0.-0.j,  0.+0.j,  0.+0.j, -0.+0.j, -0.-0.j, -1.-0.j]), '\n\nCrystal (Cartesian):\n\n', array([[[ 0.   +0.j,  0.   +0.j, -0.825+0.j],
#         [ 0.   +0.j, -0.   +0.j, -0.   +0.j],
#         [-0.825+0.j, -0.   +0.j, -0.   +0.j]],
#
#        [[ 0.   +0.j, -0.   +0.j, -0.   +0.j],
#         [-0.   +0.j,  0.   +0.j, -0.825+0.j],
#         [-0.   +0.j, -0.825+0.j, -0.   +0.j]],
#
#        [[-0.825+0.j, -0.   +0.j, -0.   +0.j],
#         [-0.   +0.j, -0.825+0.j, -0.   +0.j],
#         [-0.   +0.j, -0.   +0.j,  1.65 +0.j]]]), '\n\nAtom (Cartesian):\n\n', array([[[ 4.098+0.j,  0.   +0.j, -0.413+0.j],
#         [ 0.   +0.j, -4.098+0.j, -0.   +0.j],
#         [-0.413+0.j, -0.   +0.j, -0.   +0.j]],
#
#        [[ 0.   +0.j, -4.098+0.j, -0.   +0.j],
#         [-4.098+0.j, -0.   +0.j, -0.413+0.j],
#         [-0.   +0.j, -0.413+0.j, -0.   +0.j]],
#
#        [[-0.413+0.j, -0.   +0.j, -0.   +0.j],
#         [-0.   +0.j, -0.413+0.j, -0.   +0.j],
#         [-0.   +0.j, -0.   +0.j,  0.825+0.j]]]), '\n\nStruct. factor (Cartesian):\n\n', array([[[-1.-0.j, -0.-0.j, -0.+0.j],
#         [-0.-0.j,  1.-0.j,  0.-0.j],
#         [-0.+0.j,  0.-0.j, -0.+0.j]],
#
#        [[-0.-0.j,  1.-0.j,  0.-0.j],
#         [ 1.-0.j, -0.-0.j,  0.-0.j],
#         [ 0.-0.j,  0.-0.j,  0.+0.j]],
#
#        [[-0.+0.j,  0.-0.j, -0.+0.j],
#         [ 0.-0.j,  0.-0.j,  0.+0.j],
#         [-0.+0.j,  0.+0.j, -0.-0.j]]]), '\n')
# === Success!
# === Trying to load crystal data using CCTBX module...
#
# Crystal properties
#
#                     CIF file:  Spacegroup # 186
#                      Lattice:  3.250 3.250 5.210 90.00 90.00 120.00
#                    All sites:
#                Site selected:  2 b
#                  Site vector:  0.333 -0.333 0.949
#        No. of spacegroup ops:  12
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  2
#    No. of pg ops for crystal:  12
#
# Tensor properties
#
#              Required parity:  Odd
#           Required time sym.:  Even
#                          hkl:  [1.0, 1.0, 5.0]
#                 Site allowed:  No
#    Structure factor for site:  -0.00+0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
# ('\nTensor components\n', '\n         Crystal (spherical):  ', array([ 0.+0.j, -0.+0.j, -0.+0.j,  1.+0.j,  0.+0.j, -0.-0.j, -0.+0.j]), '\n            Atom (spherical):  ', array([ 1.   +0.j, -0.   +0.j, -0.   -0.j,  0.802+0.j,  0.   -0.j,
#        -0.   -0.j, -1.   -0.j]), '\n  Struct. factor (spherical):  ', array([ 1.+0.j,  0.+0.j, -0.-0.j,  0.-0.j,  0.-0.j,  0.-0.j, -1.-0.j]), '\n\nCrystal (Cartesian):\n\n', array([[[-0.   +0.j, -0.   +0.j, -1.717+0.j],
#         [ 0.   +0.j, -0.   +0.j, -0.   +0.j],
#         [-1.717+0.j, -0.   +0.j, -0.   +0.j]],
#
#        [[ 0.   +0.j, -0.   +0.j, -0.   +0.j],
#         [-0.   +0.j,  0.   +0.j, -1.717+0.j],
#         [-0.   +0.j, -1.717+0.j, -0.   +0.j]],
#
#        [[-1.717+0.j, -0.   +0.j, -0.   +0.j],
#         [-0.   +0.j, -1.717+0.j, -0.   +0.j],
#         [-0.   +0.j, -0.   +0.j,  3.434+0.j]]]), '\n\nAtom (Cartesian):\n\n', array([[[ 2.395+0.j,  0.   +0.j, -0.858+0.j],
#         [ 0.   +0.j, -2.395+0.j, -0.   +0.j],
#         [-0.858+0.j, -0.   +0.j, -0.   +0.j]],
#
#        [[ 0.   +0.j, -2.395+0.j, -0.   +0.j],
#         [-2.395+0.j, -0.   +0.j, -0.858+0.j],
#         [-0.   +0.j, -0.858+0.j, -0.   +0.j]],
#
#        [[-0.858+0.j, -0.   +0.j, -0.   +0.j],
#         [-0.   +0.j, -0.858+0.j, -0.   +0.j],
#         [-0.   +0.j, -0.   +0.j,  1.717+0.j]]]), '\n\nStruct. factor (Cartesian):\n\n', array([[[ 1.-0.j,  0.-0.j,  0.+0.j],
#         [ 0.-0.j, -1.+0.j, -0.-0.j],
#         [ 0.+0.j, -0.-0.j, -0.-0.j]],
#
#        [[ 0.-0.j, -1.+0.j, -0.-0.j],
#         [-1.+0.j, -0.+0.j, -0.+0.j],
#         [-0.-0.j, -0.+0.j, -0.-0.j]],
#
#        [[ 0.+0.j, -0.-0.j, -0.-0.j],
#         [-0.-0.j, -0.+0.j, -0.-0.j],
#         [-0.-0.j, -0.-0.j,  0.-0.j]]]), '\n')
# === Success!
