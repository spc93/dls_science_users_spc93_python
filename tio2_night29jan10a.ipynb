# %%
datadir='/dls/science/groups/i16/mt0/run1/'

import sys
sys.path
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from matplotlib.pyplot import *
# %matplotlib nbagg
from numpy import *
from dlstools import dataloader
from dlstools.dataloader import vec2mat
#from dlstools.quickfit import *
#from dlstools.dirty_fit import fit

d=dataloader.dlsloader(datadir+'%i.dat')
p=dataloader.tiffloader(d, lambda obj: datadir+obj.pilatus2m_path_template)
# Out:
# === Importing dlstools package
# Could not import tiff file package
# === Need to obtain specfilewrapper.py and compatible specfile.so from ERSF PyMCA package in order to load spec files

# %%
pip install matplotlib

# %% [raw]
# Matlab script: night29jan10a_new.m
#
# %TiO2 001 dichroism vs temp
# dls.dir='z:\data\2010\mt0\run1\'
#
# r1=126139
# d1=joinscans(r1+1:r1+45,'Energy');
# qplot d1.Energy d1.kphi d1.sum surf; hold off;
# view(-20,15);
# set(gca,'FontSize',14); title('T=6K');
# xlabel('Energy (keV)','FontSize',14);ylabel('\psi(deg)','FontSize',14);zlabel('Fluorescence counts','FontSize',14); title('T=6K','FontSize',16)
# %
# % r1=126185
# % d1=joinscans(r1+1:r1+45,'Energy');
# % qplot d1.Energy d1.kphi d1.sum surf; title('T=182K')
# %
# % r1=126231
# % d1=joinscans(r1+1:r1+45,'Energy');
# % qplot d1.Energy d1.kphi d1.sum surf; title('T=354K')
# %
# % r1=126277
# % d1=joinscans(r1+1:r1+45,'Energy');
# % qplot d1.Energy d1.kphi d1.sum surf; title('T=526K')
# %
# % %r1=126324
# % d1=joinscans([126325:126363,126366:126370],'Energy');
# % qplot d1.Energy d1.kphi d1.sum surf; title('T=698K')
#
# ff=20; %scale factor for difference
#
#
# r1=126139; runs=[r1+1:r1+45]; allruns{1}=runs; temp{1}=6;
# r1=126185; runs=[r1+1:r1+45]; allruns{2}=runs; temp{2}=182;
# r1=126231; runs=[r1+1:r1+45]; allruns{3}=runs; temp{3}=354;
# r1=126277; runs=[r1+1:r1+45]; allruns{4}=runs; temp{4}=526;
# runs=[126324:126363,126366:126370]; allruns{5}=runs; temp{5}=698;
#
# %phase varies from about +1 deg to -1 deg where modulation is large. Keep fixed at zero.
# %fit with extra cos function period=180 deg made no differnce (proably obvious)
#
# en=[]; meanval=[]; dich=[]; tempval=[];
# beamok=1;
#
# figure;
# ok=1;
# cols={'b','g','r','c','m'};h=[];
# for i=1:5;
#     energy=[];mumean=[]; mucos=[]; muphase=[];
#     for run=allruns{i}
#         num(run);
#         beamok=min(beamok, min(d.beamOK));
#         energy=[energy; d.Energy(1)];
#         sig=d.sum./d.ic1;
#         qplot d.kphi sig
#         [mm,p]=fit('cos_c',[max(sig)-min(sig),90,0,mean(sig)],[1,0,0,1]);
#         mumean=[mumean; p(4)]; mucos=[mucos; p(1)]; muphase=[muphase; p(3)];
#         %[mm,p]=fit('two_cos_c',[max(sig)-min(sig),90,0, 0, 180, 0, mean(sig)],[1,0,1,1,0,1,1]);
#         %mumean=[mumean; p(7)]; mucos=[mucos; p(1)]; muphase=[muphase; p(3)];
#         delete(gcf)
#
#         %to fix the bad point for a nice plot
#
#         if ok==0; %beam was lost during previous measurement...
#             %mumean(end-1)=(mumean(end-2)+mumean(end))/2; mucos(end)=(mucos(end-2)+mucos(end))/2;
#             mucos(end-1)=0
#         end
#         ok=min(d.beamOK);
#
#         en=[en; d.Energy(1)]; meanval=[meanval; p(4)]; dich=[dich; p(1)]; tempval=[tempval; temp{i}];
#     end
#     %hold all; plot(energy, mumean,'r'); hold all; plot(energy, mucos*ff,'r.-'); hold all; plot(energy, muphase*1000000,'g.-'); hold off; grid; title(['T=',num2str(temp{i}),'K'])
#     hold all; h=[h,plot(energy, mumean,cols{i},'LineWidth',2)]; hold all; plot(energy, mucos*ff,[cols{i},'-'],'LineWidth',2); hold off; grid on;
#     set(gca,'FontSize',14); xlabel('Energy (keV)','FontSize',14);ylabel('Mean and dichroic intensity ','FontSize',14);
# end
# axis tight;
# legend(h,'T=6K','T=182K','T=354K','T=526K','T=698K')
#
# qplot en tempval meanval surf; view(-10,7);
# set(gca,'FontSize',14);
# xlabel('Energy (keV)','FontSize',14);ylabel('T(K)','FontSize',14);zlabel('Dichroism','FontSize',14); title('T=6K','FontSize',16)

# %%
r1=126139
#d1=joinscans(r1+1:r1+45,'Energy');
phi_list, en_list, sum_list = [], [], []

for n in range(r1+1, r1+45 + 1):
    d(n)
    phi_list +=[d.kphi]
    sum_list += [d.sum]
    en_list += [d.Energy1 * ones(len(d.kphi))]
phi_array, sum_array, en_array = array(phi_list), array(sum_list), array(en_list)

# %%
# Out:
#   File "<ipython-input-7-7d2ed1ba2433>", line 6
#     Z = 2./exp((X-.5).^2+Y.^2)-2./exp((X+.5).^2+Y.^2);
#                       ^
# SyntaxError: invalid syntax

# %%
en_array
# Out:
# array([[4.962999, 4.962999, 4.962999, ..., 4.962999, 4.962999, 4.962999],
#        [4.963502, 4.963502, 4.963502, ..., 4.963502, 4.963502, 4.963502],
#        [4.964001, 4.964001, 4.964001, ..., 4.964001, 4.964001, 4.964001],
#        ...,
#        [4.984003, 4.984003, 4.984003, ..., 4.984003, 4.984003, 4.984003],
#        [4.984501, 4.984501, 4.984501, ..., 4.984501, 4.984501, 4.984501],
#        [4.985002, 4.985002, 4.985002, ..., 4.985002, 4.985002, 4.985002]])

# %% [markdown]
# ## edgecolors='k'

# %%
#figure().add_subplot(111, projection='3d').plot_wireframe(d.s.stoke, d.s.thp, d.s.APD); axis('tight')
#figure().add_subplot(111, projection='3d').plot_surface(d.s.stoke, d.s.thp, d.s.APD, cmap='autumn', cstride=1, rstride=1); axis('tight')
#figure().add_subplot(111, projection='3d').plot_surface(phi_array, en_array, sum_array, cmap='autumn', cstride=1, rstride=1); axis('tight')
f=figure()
f.add_subplot(111, projection='3d').plot_surface(phi_array, en_array, sum_array, cmap='autumn', edgecolors='k', linewidth=0.5,cstride=1, rstride=1); axis('tight')
#f.add_subplot(111, projection='3d').plot_surface(phi_array, en_array, sum_array, cmap='viridis', linewidth=0.25, cstride=1, rstride=1); axis('tight')
edgecolors='k'
savefig('/home/spc93/tmp/tio2.png')
#f.add_subplot(111, projection='3d').plot_surface(phi_array, en_array, sum_array, cmap='copper', linewidth=0.5, cstride=1, rstride=1); axis('tight')



#figure().add_subplot(111, projection='3d').plot_surface(phi_array, en_array, sum_array, facecolors='k', antialiased=True, cmap='autumn', cstride=1, rstride=1); axis('tight')

#rstride=1, cstride=1, facecolors=C, antialiased=True

#f.add_subplot(111, projection='3d').plot_wireframe(phi_array, en_array, sum_array, cmap='autumn', cstride=1, rstride=1); axis('tight')
#linewidth=0.5
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
savefig('/home/spc93/tmp/tio2.png')

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D

import sys
import matplotlib
print('Python version %s' % sys.version)
print('numpy version: %s' % np.__version__)
print('matplotlib version: %s' % matplotlib.__version__)

x = np.linspace(-5, 5, 200)
y = x
X,Y = np.meshgrid(x, y)
fwhm = 2.5
Z =  np.exp(-np.log(2) * (((X) ** 2 + (Y) ** 2) / (fwhm / 2) ** 2))


cmap = plt.get_cmap('Spectral')
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=cmap, edgecolors='k')

plt.show()
# Out:
# Python version 3.8.0 | packaged by conda-forge | (default, Nov 22 2019, 19:11:38)
# [GCC 7.3.0]
# numpy version: 1.20.2
# matplotlib version: 3.1.2
# <img src="data:image/png;base64,..." width="640">
