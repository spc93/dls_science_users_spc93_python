# %%
# test nexus load speed
# %matplotlib notebook

import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')


from time import sleep, asctime
from dlstools.pdnx import *
from matplotlib.pyplot import *

p='/dls/staging/dls/i16/data/2020/mm25913-2/%i.nxs'



#ff = figure()

#for scan in range(854160, 862373): # full l3 list
#for scan in range(854160, 854260): # short test set
#for scan in range(854160, 854180): # very short test set
for scan in range(854160, 856160): # 20 x short test set


    _start_time = time.time()
    n = pdnx(p % scan)
    print(asctime() + '\t' + p % scan, '%.2f sec' % (time.time()-_start_time))
# Out:
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854160.nxs 0.04 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854161.nxs 0.03 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854162.nxs 0.04 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854163.nxs 0.02 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854164.nxs 0.02 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854165.nxs 0.02 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854166.nxs 0.02 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854167.nxs 0.02 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854168.nxs 0.02 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854169.nxs 0.02 sec
# Mon Dec 20 15:05:39 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854170.nxs 0.02 sec
# ...

# %%
print(asctime() + '\t' + p % scan)
# Out:
# Mon Dec 20 14:59:12 2021	/dls/staging/dls/i16/data/2020/mm25913-2/854160.nxs

# %%
asctime() + '\t' + p + '\t %.1f sec' % (1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-82330ab1b596> in <module>
# ----> 1 asctime() + '\t' + p + '\t %.1f sec' % (1,2)
#
# TypeError: not all arguments converted during string formatting

# %%
atplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import time

def pltsin(ax, colors=['b']):
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        for color in colors:
            y = np.random.random(size=(100,1))
            ax.plot(x, y, color)
    fig.canvas.draw()

fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
for f in range(5):
    pltsin(ax, ['b', 'r'])
    time.sleep(1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pickle
a = {'thing1':[1,2,3], 'thing2': 'ggg'}
pickle.dump(a, open('/dls/science/users/spc93/data/ggg_test_res_dict.p', "wb" ) )

# %%
aa = pickle.load( open('/dls/science/users/spc93/data/ggg_test_res_dict.p' , "rb" ) ) # load back from pickle file

# %%
aa
# Out:
# {'thing1': [1, 2, 3], 'thing2': 'ggg'}
