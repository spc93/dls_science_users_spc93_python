# %%
# use python 3.6 or 3.7 environment

# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *

from dlstools.quickfit import *
import matplotlib.pyplot as plt

#%matplotlib inline
# %matplotlib notebook
#%matplotlib nbagg

#p='/dls/i16/data/2022/cm28156-15/%i.nxs'
p='/dls/i12/data/2022/mg29851-1/rawdata/%i.nxs'
# Out:
# === Importing dlstools package

# %%
n = pdnx(p % 110812)
print(n.nx.tree)
# Out:
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       cam1:NXcollection
#         cam1_roll = -0.00300197
#         cam1_x = 140.56
#         cam1_z = -96.12984375
#       dcm1_cap_1:NXcollection
#         dcm1_cap_1 = 74.535
#       dcm1_cap_2:NXcollection
#         dcm1_cap_2 = 75.685
#       det_cfg:NXcollection
#         cam_adc_mode = 'One ADC'
#         cam_bin_x = '1'
#         cam_bin_y = '1'
#         cam_img_size_x = '2560'
#         cam_img_size_y = '2160'
#         cam_model = 'pco.edge'
#         cam_pixel_rate = '286000000 Hz'
#         cam_roi_min_x = '0'
#         cam_roi_min_y = '0'
#         cam_roi_size_x = '2560'
#         cam_roi_size_y = '2160'
#         cam_sensor_size_x = '2560'
#         cam_sensor_size_y = '2160'
#         cam_timestamp_mode = 'BCD+ASCII'
#         readout_time_sec = 0.011
#       f1 = 'clear'
#         @local_name = 'f1.f1'
#       f2 = 'clear'
# ...

# %%
import numpy as np
#log book: https://dlsltd-my.sharepoint.com/:f:/g/personal/thomas_connolley_diamond_ac_uk/EigjhYAPe2lBsJdGYWhFgRIB5Vm_heUDJurYHTDnXc5TYg?e=RyMmO1

cathode_width = 14000
cathode_tickness = 60
np.arcsin(cathode_tickness/cathode_width) * 180/np.pi
# Out:
# 0.2455540924704662
