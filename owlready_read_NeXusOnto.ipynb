# %%
from owlready2 import *
from pprint import pprint

#in_path = '/home/spc93/ontology/'
#onto_iri = 'http://purl.org/nexusformat/NeXusOntology'
#onto_path.append(in_path)
#onto = get_ontology(onto_iri)
onto = get_ontology('/home/spc93/ontology/NeXusOntology.owl').load()

class_list = list(onto.classes())
pprint(class_list)

prop_list = list(onto.properties())
pprint(prop_list)

pprint(onto.metadata.comment)
# Out:
# [NeXusOntology.dataset,
#  NeXusOntology.NXobject,
#  NeXusOntology.NeXusBaseClass,
#  NeXusOntology.NX_UNITLESS,
#  NeXusOntology.NXaperture,
#  NeXusOntology.NX_LENGTH,
#  NeXusOntology.NXattenuator,
#  NeXusOntology.NX_CROSS_SECTION,
#  NeXusOntology.NX_DIMENSIONLESS,
#  NeXusOntology.NXbeam,
#  NeXusOntology.NX_ENERGY,
#  NeXusOntology.NX_WAVELENGTH,
#  NeXusOntology.NX_ANGLE,
#  NeXusOntology.NX_ANY,
#  NeXusOntology.NX_FLUX,
#  NeXusOntology.NX_FREQUENCY,
#  NeXusOntology.NXbeam_stop,
#  NeXusOntology.NXbending_magnet,
#  NeXusOntology.NX_CURRENT,
#  NeXusOntology.NXcapillary,
#  NeXusOntology.NXcite,
#  NeXusOntology.NXcollection,
#  NeXusOntology.NXcollimator,
#  NeXusOntology.NXcrystal,
#  NeXusOntology.NX_VOLUME,
#  NeXusOntology.NX_WAVENUMBER,
#  NeXusOntology.NX_MASS_DENSITY,
#  NeXusOntology.NX_TEMPERATURE,
#  NeXusOntology.NXcylindrical_geometry,
#  NeXusOntology.NXdata,
#  NeXusOntology.NX_PER_LENGTH,
#  NeXusOntology.NX_TIME_OF_FLIGHT,
#  NeXusOntology.NXdetector,
# ...

# %%
cl = class_list[39]
print(cl.name, '\n')
print(cl.iri, '\n')
pprint(cl.is_a)
# Out:
# NXdisk_chopper
#
# http://purl.org/nexusformat/NeXusOntology#NXdisk_chopper
#
# [NeXusOntology.NeXusBaseClass,
#  NeXusOntology.NXdisk_chopper.type.some(NeXusOntology.NX_UNITLESS),
#  NeXusOntology.NXdisk_chopper.rotation_speed.some(NeXusOntology.NX_FREQUENCY),
#  NeXusOntology.NXdisk_chopper.slits.some(NeXusOntology.NX_UNITLESS),
#  NeXusOntology.NXdisk_chopper.slit_angle.some(NeXusOntology.NX_ANGLE),
#  NeXusOntology.NXdisk_chopper.pair_separation.some(NeXusOntology.NX_LENGTH),
#  NeXusOntology.NXdisk_chopper.slit_edges.some(NeXusOntology.NX_ANGLE),
#  NeXusOntology.NXdisk_chopper.top_dead_center.some(NeXusOntology.NX_TIME),
#  NeXusOntology.NXdisk_chopper.beam_position.some(NeXusOntology.NX_ANGLE),
#  NeXusOntology.NXdisk_chopper.radius.some(NeXusOntology.NX_LENGTH),
#  NeXusOntology.NXdisk_chopper.slit_height.some(NeXusOntology.NX_LENGTH),
#  NeXusOntology.NXdisk_chopper.phase.some(NeXusOntology.NX_ANGLE),
#  NeXusOntology.NXdisk_chopper.delay.some(NeXusOntology.NX_TIME),
# ...
