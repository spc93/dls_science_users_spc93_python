# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *


pi06 = '/dls/science/users/spc93/misc_nexus_data/fajin/i06-%i.nxs'
pi06_1 = '/dls/science/users/spc93/misc_nexus_data/fajin/i06-1-%i.nxs'
pi10 = '/dls/science/users/spc93/misc_nexus_data/fajin/i10-%i.nxs'
pi21 = '/dls/science/users/spc93/misc_nexus_data/fajin/i21-%i.nxs'

# %%
print('=== i06 ===\n\n')
for i in [28, 251]:
    n = pdnx(pi06 % i)
    print(n.nx.tree)
    try:
        n.nx.plot()
    except:
        pass

print('=== i06-1 ===\n\n')
for i in [29, 30, 31]:
    n = pdnx(pi06_1 % i)
    print(n.nx.tree)
    try:
        n.nx.plot()
    except:
        pass

print('=== i10 ===\n\n')
for i in [44, 45, 46]:
    n = pdnx(pi10 % i)
    print(n.nx.tree)
    try:
        n.nx.plot()
    except:
        pass

print('=== i10 ===\n\n')
n = pdnx(pi21 % 16)
print(n.nx.tree)
try:
    n.nx.plot()
except:
    pass
# Out:
# === i06 ===
#
#
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   @file_name = '/scratch/gda_versions/gda-master-20211006/gda_...'
#   entry:NXentry
#     @default = 'medipix'
#     diamond_scan:NXcollection
#       duration = 4709
#         @target = '/entry/diamond_scan/duration'
#         @units = 'ms'
#       end_time = '2021-11-02T15:30:51.879'
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-11-02T15:30:47.334', '2021-11-02T15:30:47.365', '...
#       point_start_times = ['2021-11-02T15:30:47.334', '2021-11-02T15:30:47.365', '...
#       scan_command = 'scan t 1 10 1 medipix 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 4710
#         @units = 'ms'
#       scan_dead_time_percent = 100.02123260498047
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-11-02T15:30:47.170'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       EC1:NXcollection
#         temperature = 21.98
#           @units = '°C'
#       OH1:NXcollection
#         temperature = 22.2
#           @units = '°C'
#       beamline = 'i06'
#       d4:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d5:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d6:NXcollection
#         y = 0.0
#           @units = 'mm'
#       d7:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d7a:NXcollection
#         x = 0.0
#           @units = 'mm'
#       end_station = 'PEEM'
#       id:NXinsertion_device
#         gap = 0.0
#           @units = 'mm'
#         harmonic = 1
#         idd:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         idu:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         polarisation = 'la'
#         pugap = 0.0
#           @units = 'mm'
#         source_mode = 'idd'
#         taper = 0.0
#           @units = 'µrad'
#         type = 'undulator'
#       leem:NXcollection
#         fov = 5.0
#         obj = 1.0
#         objStigmA = 3.0
#         objStigmB = 4.0
#         rot = 0.0
#           @units = 'deg'
#         stv = 2.5
#       m1:NXmirror
#         T1 = 17.2
#           @units = '°C'
#         T2 = 14.5
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m3:NXmirror
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m4:NXmirror
#         pitch = 0.0
#           @units = 'deg'
#         roll = 0.0
#           @units = 'deg'
#       m5:NXmirror
#         bend1 = 0.0
#           @units = 'deg'
#         bend2 = 0.0
#           @units = 'deg'
#         pitch = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         x1 = 0.0
#           @units = 'mm'
#         x2 = 0.0
#           @units = 'mm'
#       m6:NXmirror
#         T1 = 18.4
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         type = 'Switch Mirror'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       medipix:NXdetector
#         count_time = float64(10)
#           @local_name = 'medipix.count_time'
#         data -> medipix-28.hdf['/entry/instrument/detector/data']
#         description = 'MediPix - a water cold X-ray camera.'
#         local_name = 'medipix'
#         manufacturer = 'Simulated detector'
#         medipix_settings:NXcollection
#           bit_depth = 24
#           configuration_file = 'BL06I-EA-DET-02:CAM:FullFileName_RBV'
#           configuration_file_name = 'BL06I-EA-DET-02:CAM:FileName_RBV'
#           configuration_file_path = 'BL06I-EA-DET-02:CAM:FilePath_RBV'
#           equalization_files = 'BL06I-EA-DET-02:CAM:EqFilePath_RBV'
#           exposure = 1.0
#             @units = 's'
#           gain_mode = 'BL06I-EA-DET-02:CAM:GainMode_RBV'
#           image_mode = 'Single'
#           image_size_x = 'Could not get data from ws128-AD-SIM-01:ArraySizeX_RBV :...'
#           image_size_y = 960
#           number_of_image = 1
#           period = 1.005
#             @units = 's'
#           region_size_x = 1280
#           region_size_y = 960
#           region_start_x = 0
#           region_start_y = 0
#           sensor_size_x = 1280
#           sensor_size_y = 960
#           threshold_energy_0 = 'BL06I-EA-DET-02:CAM:ThresholdEnergy0_RBV'
#         model = 'Basic simulator'
#       name = 'PEEM'
#       pgm:NXmonochromator
#         400llmmEnergyGradient = 0.98642902
#         400llmmEnergyReference = 248.0
#         400llmmGratingOffset = -0.056082
#         400llmmMirrorOffset = -0.02633
#         T1 = 16.0
#           @units = '°C'
#         cff = 2.25
#         energy = 800.0
#           @units = 'eV'
#         gratPitch = 0.0
#           @units = 'deg'
#         grating = 150
#           @units = 'lines/mm'
#         mirrorPitch = 0.0
#           @units = 'deg'
#       ps:NXcollection
#         phi = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       s1:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s2:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s3:NXslit
#         x_centre = 0.0
#           @units = 'mm'
#         x_gap = 0.0
#           @units = 'mm'
#         x_neg = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_centre = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_neg = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s4:NXslit
#         x_gap = 0.0
#           @units = 'µm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'µm'
#         y_pos = 0.0
#           @units = 'mm'
#       s5:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       source:NXsource
#         current = 250.0
#           @units = 'mA'
#         energy = 3.0
#           @units = 'GeV'
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#       t:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 't'
#         name = 't'
#         soft_limit_max = 2000000000.0
#         soft_limit_min = -2000000000.0
#         value = float64(10)
#           @gda_field_name = 't'
#           @local_name = 't.t'
#           @target = '/entry/instrument/t/value'
#           @units = 'mm'
#       xbpm1:NXcollection
#         x = -0.0303253
#           @units = 'mm'
#         y = 0.0489596
#           @units = ''
#       xbpm2:NXcollection
#         x = 0.213676
#           @units = 'mm'
#         y = 0.517054
#           @units = ''
#     medipix:NXdata
#       @axes = ['t', '.', '.']
#       @signal = 'data'
#       @t_indices = 0
#       data -> medipix-28.hdf['/entry/instrument/detector/data']
#       t -> /entry/instrument/t/value
#     program_name = 'GDA 9.23.0'
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#           @units = 'mm'
#         extent = 0.0
#         flux = 0.0
#         incident_beam_divergence = 0.0
#         incident_energy = 800.0
#           @units = 'eV'
#         incident_polarization = float64(4)
#     scan_command -> /entry/diamond_scan/scan_command
#     scan_shape -> /entry/diamond_scan/scan_shape
#     start_time -> /entry/diamond_scan/start_time
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Fajin Yuan'
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   @file_name = '/scratch/data/i06/2021/0-0/i06-251.nxs'
#   entry:NXentry
#     duration = 226
#       @units = 'ms'
#     end_time = '2021-04-27T14:46:40.177+01'
#     instrument:NXinstrument
#       d5:NXcollection
#         x = 0.0
#       d6:NXcollection
#         y = 0.0
#       d7:NXcollection
#         ax = 0.0
#         x = 0.0
#       ds:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 'ds'
#         name = 'ds'
#         soft_limit_max = 1.7976931348623157e+308
#         soft_limit_min = -1.7976931348623157e+308
#         value = float64(10)
#           @gda_field_name = 'ds'
#           @local_name = 'ds.value'
#           @target = '/entry/instrument/ds/value'
#       id:NXinsertion_device
#         idd:NXcollection
#           brp = 0.0
#           gap = 0.0
#           la_angle = 0.0
#           trp = 0.0
#         idu:NXcollection
#           brp = 0.0
#           gap = 0.0
#           la_angle = 0.0
#           trp = 0.0
#         type = 'undulator'
#       m1:NXmirror
#         pitch = 0.0
#         qg = 0.0
#         x = 0.0
#         yaw = 0.0
#       m3:NXmirror
#         pitch = 0.0
#         qg = 0.0
#         x = 0.0
#       m6:NXmirror
#         pitch = 0.0
#         qg = 0.0
#         type = 'Switch Mirror'
#         x = 0.0
#         yaw = 0.0
#       medipix:NXdetector
#         colour_mode = 'Mono'
#         count_time = float64(10)
#           @local_name = 'medipix.count_time'
#         data -> medipix-251.hdf['/entry/instrument/detector/data']
#         data_type = 'UInt8'
#         description = 'MediPix - a water cold X-ray camera., Simulated detector,'
#         local_name = 'medipix'
#         medipix_settings:NXcollection
#           binning_x = 1
#           binning_y = 1
#           gain = 1.0
#           manufacturer = 'Simulated detector'
#           model = 'Basic simulator'
#           temperature_actual = 25.0
#           temperature_set = 25.0
#         serial_number = 'Not Available'
#       pgm:NXmonochromator
#         cff = 2.25
#         energy = 0.0
#         grating = 400
#         gratpitch = 0.0
#         pitch = 0.0
#       ps:NXcollection
#         x = 0.0
#         y = 0.0
#       s1:NXslit
#         x_gap = 0.0
#         y_gap = 0.0
#       s4:NXslit
#         x_gap = 0.0
#         x_pos = 0.0
#         y_gap = 0.0
#         y_pos = 0.0
#       source:NXsource
#         current = 250.0
#         energy = 3.0
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#     medipix:NXdata
#       @axes = ['ds', '.', '.']
#       @ds_indices = 0
#       @signal = 'data'
#       data -> medipix-251.hdf['/entry/instrument/detector/data']
#       ds -> /entry/instrument/ds/value
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#         extent = 10.0
#         flux = 10.0
#         incident_beam_divergence = 10.0
#         incident_energy = 0.0
#         incident_polarization = 'nc'
#     start_time = '2021-04-27T14:46:39.951+01'
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Yuan, F (Fajin)'
# === i06-1 ===
#
#
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   @file_name = '/scratch/gda_versions/gda-master-20211006/gda_...'
#   entry:NXentry
#     @default = 'ca61sr'
#     ca61sr:NXdata
#       @axes = 't'
#       @signal = 'value'
#       @t_indices = 0
#       t -> /entry/instrument/t/value
#       value -> /entry/instrument/ca61sr/value
#     diamond_scan:NXcollection
#       duration = 732
#         @target = '/entry/diamond_scan/duration'
#         @units = 'ms'
#       end_time = '2021-11-02T15:39:29.082'
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-11-02T15:39:28.541', '2021-11-02T15:39:28.553', '...
#       point_start_times = ['2021-11-02T15:39:28.541', '2021-11-02T15:39:28.553', '...
#       scan_command = 'scan t 1 10 1 ca61sr 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 733
#         @units = 'ms'
#       scan_dead_time_percent = 100.13661193847656
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-11-02T15:39:28.350'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       EC1:NXcollection
#         temperature = 21.98
#           @units = '°C'
#       OH1:NXcollection
#         temperature = 22.2
#           @units = '°C'
#       beamline = 'i06-1'
#       ca61sr:NXpositioner
#         @gda_scan_role = 'monitor_per_point'
#         @gda_scannable_name = 'ca61sr'
#         name = 'ca61sr'
#         value = float64(10)
#           @gda_field_name = 'ca61sr'
#           @local_name = 'ca61sr.ca61sr'
#           @target = '/entry/instrument/ca61sr/value'
#       chp:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d4:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d8:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d9:NXcollection
#         y = 0.0
#           @units = 'mm'
#       d10:NXcollection
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       d11:NXcollection
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       d12:NXcollection
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       end_station = 'Magnet'
#       hm:NXcollection
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       id:NXinsertion_device
#         gap = 0.0
#           @units = 'mm'
#         harmonic = 1
#         idd:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         idu:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         polarisation = 'pc'
#         pugap = 0.0
#           @units = 'mm'
#         source_mode = 'dmu'
#         taper = 0.0
#           @units = 'µrad'
#         type = 'undulator'
#       m1:NXmirror
#         T1 = 17.2
#           @units = '°C'
#         T2 = 14.5
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m6:NXmirror
#         T1 = 18.4
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         type = 'Switch Mirror'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m7:NXmirror
#         amp_gain = '10^3 V/A'
#         draincurrent = 1.0
#         pitch = 0.0
#           @units = 'µrad'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       name = 'Magnet'
#       pgm:NXmonochromator
#         400llmmEnergyGradient = 0.98642902
#         400llmmEnergyReference = 248.0
#         400llmmGratingOffset = -0.056082
#         400llmmMirrorOffset = -0.02633
#         T1 = 16.0
#           @units = '°C'
#         cff = 2.25
#         energy = 800.0
#           @units = 'eV'
#         gratPitch = 0.0
#           @units = 'deg'
#         grating = 1200
#           @units = 'lines/mm'
#         mirrorPitch = 0.0
#           @units = 'deg'
#       s1:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s2:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s3:NXslit
#         x_centre = 0.0
#           @units = 'mm'
#         x_gap = 0.0
#           @units = 'mm'
#         x_neg = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_centre = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_neg = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s6:NXslit
#         x_gap = 0.0
#           @units = 'µm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'µm'
#         y_pos = 0.0
#           @units = 'mm'
#       scm:NXcollection
#         T_sample = 250.001
#           @units = 'K'
#         amp_1_gain = 1000000000.0
#         amp_1_mode = 'high speed'
#         amp_2_gain = 100000000.0
#         amp_2_mode = 'low noise'
#         amp_3_gain = 1000.0
#         amp_3_mode = 'low noise'
#         amp_4_gain = 100000000.0
#         amp_4_mode = 'high speed'
#         field_sum = 0.0
#           @units = 'T'
#         field_x = 0.0
#           @units = 'T'
#         field_y = 0.0
#           @units = 'T'
#         field_z = 0.0
#           @units = 'T'
#         helium_depth_A = 360.0
#           @units = 'mm'
#         helium_depth_B = 0.0
#           @units = 'mm'
#         loop1:NXcollection
#           heater_PID_D = 0.0
#           heater_PID_I = 9.0
#           heater_PID_P = 2.5
#           heater_actual_output = 4.0
#             @units = '%'
#           heater_manual_output = 0.0
#             @units = '%'
#           heater_output_range = 'High'
#           heater_ramping = 'NO'
#           heater_ramping_rate = 1.0
#           heater_target_temp = 250.0
#             @units = 'K'
#           heater_type = 'PID'
#         loop2:NXcollection
#           heater_PID_D = 0.0
#           heater_PID_I = 20.0
#           heater_PID_P = 0.2
#           heater_actual_output = 0.0
#             @units = '%'
#           heater_manual_output = 0.5
#             @units = '%'
#           heater_output_range = 'Low'
#           heater_ramping = 'NO'
#           heater_ramping_rate = 1.0
#           heater_target_temp = 4.0
#             @units = 'K'
#           heater_type = 'OFF'
#         mode = 'UNIAXIAL_Z'
#         pressure_prechamber = 5.42065e-09
#           @units = 'mbar'
#         pressure_sample = 3.16652e-10
#           @units = 'mbar'
#         sensor_A = 4.27
#           @units = 'K'
#         sensor_B = 4.244
#           @units = 'K'
#         sensor_C = 303.398
#           @units = 'K'
#         sensor_D = 18.934
#           @units = '%'
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       source:NXsource
#         current = 250.0
#           @units = 'mA'
#         energy = 3.0
#           @units = 'GeV'
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#       t:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 't'
#         name = 't'
#         soft_limit_max = 2000000000.0
#         soft_limit_min = -2000000000.0
#         value = float64(10)
#           @gda_field_name = 't'
#           @local_name = 't.t'
#           @target = '/entry/instrument/t/value'
#           @units = 'mm'
#       xbpm1:NXcollection
#         x = -0.0303253
#           @units = 'mm'
#         y = 0.0489596
#           @units = ''
#       xbpm2:NXcollection
#         x = 0.213676
#           @units = 'mm'
#         y = 0.517054
#           @units = ''
#     program_name = 'GDA 9.23.0'
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#           @units = 'mm'
#         extent = 0.0
#         flux = 0.0
#         incident_beam_divergence = 0.0
#         incident_energy = 800.0
#           @units = 'eV'
#         incident_polarization = float64(4)
#     scan_command -> /entry/diamond_scan/scan_command
#     scan_shape -> /entry/diamond_scan/scan_shape
#     start_time -> /entry/diamond_scan/start_time
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Fajin Yuan'
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   @file_name = '/scratch/gda_versions/gda-master-20211006/gda_...'
#   entry:NXentry
#     @default = 'pixis'
#     diamond_scan:NXcollection
#       duration = 4613
#         @target = '/entry/diamond_scan/duration'
#         @units = 'ms'
#       end_time = '2021-11-02T15:43:00.471'
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-11-02T15:42:56.042', '2021-11-02T15:42:56.063', '...
#       point_start_times = ['2021-11-02T15:42:56.042', '2021-11-02T15:42:56.063', '...
#       scan_command = 'scan t 1 10 1 pixis 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 4614
#         @units = 'ms'
#       scan_dead_time_percent = 100.02167510986328
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-11-02T15:42:55.858'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       EC1:NXcollection
#         temperature = 21.98
#           @units = '°C'
#       OH1:NXcollection
#         temperature = 22.2
#           @units = '°C'
#       beamline = 'i06-1'
#       chp:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d4:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d8:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d9:NXcollection
#         y = 0.0
#           @units = 'mm'
#       d10:NXcollection
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       d11:NXcollection
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       d12:NXcollection
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       ddiff:NXcollection
#         2theta = 0.0
#           @units = 'deg'
#         amp_1_gain = 1000.0
#         amp_1_mode = 'high speed'
#         amp_2_gain = 1000000000.0
#         amp_2_mode = 'high speed'
#         amp_3_gain = 1000000.0
#         amp_3_mode = 'high speed'
#         amp_4_gain = 1000000000.0
#         amp_4_mode = 'high speed'
#         chi = 0.0
#           @units = 'deg'
#         dddy = 0.0
#           @units = 'mm'
#         phi = 0.0
#           @units = 'deg'
#         pressure_sample = 3.16652e-10
#           @units = 'mbar'
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         z = 0.0
#           @units = 'mm'
#       end_station = 'DD'
#       hm:NXcollection
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       id:NXinsertion_device
#         gap = 0.0
#           @units = 'mm'
#         harmonic = 1
#         idd:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         idu:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         polarisation = 'lv'
#         pugap = 0.0
#           @units = 'mm'
#         source_mode = 'idd'
#         taper = 0.0
#           @units = 'µrad'
#         type = 'undulator'
#       lakeshore336:NXsensor
#         cryostat = 380.35539383946093
#           @units = 'K'
#         demand = 0.0
#           @units = 'K'
#         heater = 19.100200100070218
#           @units = '%'
#         heater_range = 0
#         sample = 413.6326439568714
#           @units = 'K'
#         shield = 257.60333087689327
#           @units = 'K'
#       m1:NXmirror
#         T1 = 17.2
#           @units = '°C'
#         T2 = 14.5
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m6:NXmirror
#         T1 = 18.4
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         type = 'Switch Mirror'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m7:NXmirror
#         amp_gain = '10^3 V/A'
#         draincurrent = 4103.034202268965
#         pitch = 0.0
#           @units = 'µrad'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       name = 'DD'
#       pgm:NXmonochromator
#         400llmmEnergyGradient = 0.98642902
#         400llmmEnergyReference = 248.0
#         400llmmGratingOffset = -0.056082
#         400llmmMirrorOffset = -0.02633
#         T1 = 16.0
#           @units = '°C'
#         cff = 2.25
#         energy = 800.0
#           @units = 'eV'
#         gratPitch = 0.0
#           @units = 'deg'
#         grating = 400
#           @units = 'lines/mm'
#         mirrorPitch = 0.0
#           @units = 'deg'
#       pixis:NXdetector
#         count_time = float64(10)
#           @local_name = 'pixis.count_time'
#         data -> pixis-30.hdf['/entry/instrument/detector/data']
#         description = 'PIXIS - a water cold in-vacuum X-ray camera.'
#         local_name = 'pixis'
#         manufacturer = 'Simulated detector'
#         model = 'Basic simulator'
#         pixis_settings:NXcollection
#           bin_x = 1
#           bin_y = 1
#           bit_depth = 16
#           exposure = 1.0
#             @units = 's'
#           image_mode = 'Single'
#           image_size_x = 'Could not get data from ws128-AD-SIM-01:ArraySizeX_RBV :...'
#           image_size_y = 960
#           number_of_image = 1
#           period = 0.005
#             @units = 's'
#           region_size_x = 1280
#           region_size_y = 960
#           region_start_x = 0
#           region_start_y = 0
#           sensor_size_x = 1280
#           sensor_size_y = 960
#           speed = 2.0
#           temperature_measured = 25.0
#           temperature_set = 25.0
#         serial_number = '02131515'
#       s1:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s2:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s3:NXslit
#         x_centre = 0.0
#           @units = 'mm'
#         x_gap = 0.0
#           @units = 'mm'
#         x_neg = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_centre = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_neg = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s6:NXslit
#         x_gap = 0.0
#           @units = 'µm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'µm'
#         y_pos = 0.0
#           @units = 'mm'
#       source:NXsource
#         current = 250.0
#           @units = 'mA'
#         energy = 3.0
#           @units = 'GeV'
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#       t:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 't'
#         name = 't'
#         soft_limit_max = 2000000000.0
#         soft_limit_min = -2000000000.0
#         value = float64(10)
#           @gda_field_name = 't'
#           @local_name = 't.t'
#           @target = '/entry/instrument/t/value'
#           @units = 'mm'
#       xbpm1:NXcollection
#         x = -0.0303253
#           @units = 'mm'
#         y = 0.0489596
#           @units = ''
#       xbpm2:NXcollection
#         x = 0.213676
#           @units = 'mm'
#         y = 0.517054
#           @units = ''
#     pixis:NXdata
#       @axes = ['t', '.', '.']
#       @signal = 'data'
#       @t_indices = 0
#       data -> pixis-30.hdf['/entry/instrument/detector/data']
#       t -> /entry/instrument/t/value
#     program_name = 'GDA 9.23.0'
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#           @units = 'mm'
#         extent = 0.0
#         flux = 0.0
#         incident_beam_divergence = 0.0
#         incident_energy = 800.0
#           @units = 'eV'
#         incident_polarization = float64(4)
#     scan_command -> /entry/diamond_scan/scan_command
#     scan_shape -> /entry/diamond_scan/scan_shape
#     start_time -> /entry/diamond_scan/start_time
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Fajin Yuan'
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   @file_name = '/scratch/gda_versions/gda-master-20211006/gda_...'
#   entry:NXentry
#     @default = 'ca63sr'
#     ca63sr:NXdata
#       @axes = 't'
#       @signal = 'value'
#       @t_indices = 0
#       t -> /entry/instrument/t/value
#       value -> /entry/instrument/ca63sr/value
#     diamond_scan:NXcollection
#       duration = 717
#         @target = '/entry/diamond_scan/duration'
#         @units = 'ms'
#       end_time = '2021-11-02T15:45:35.844'
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-11-02T15:45:35.281', '2021-11-02T15:45:35.296', '...
#       point_start_times = ['2021-11-02T15:45:35.280', '2021-11-02T15:45:35.295', '...
#       scan_command = 'scan t 1 10 1 ca63sr 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 718
#         @units = 'ms'
#       scan_dead_time_percent = 100.13947296142578
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-11-02T15:45:35.127'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       EC1:NXcollection
#         temperature = 21.98
#           @units = '°C'
#       OH1:NXcollection
#         temperature = 22.2
#           @units = '°C'
#       beamline = 'i06-1'
#       ca63sr:NXpositioner
#         @gda_scan_role = 'monitor_per_point'
#         @gda_scannable_name = 'ca63sr'
#         name = 'ca63sr'
#         value = float64(10)
#           @gda_field_name = 'ca63sr'
#           @local_name = 'ca63sr.ca63sr'
#           @target = '/entry/instrument/ca63sr/value'
#       chp:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d4:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d8:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d9:NXcollection
#         y = 0.0
#           @units = 'mm'
#       d10:NXcollection
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       d11:NXcollection
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       d12:NXcollection
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       end_station = 'XABS'
#       hm:NXcollection
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       id:NXinsertion_device
#         gap = 0.0
#           @units = 'mm'
#         harmonic = 1
#         idd:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         idu:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         polarisation = 'lh'
#         pugap = 0.0
#           @units = 'mm'
#         source_mode = 'dpu'
#         taper = 0.0
#           @units = 'µrad'
#         type = 'undulator'
#       m1:NXmirror
#         T1 = 17.2
#           @units = '°C'
#         T2 = 14.5
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m6:NXmirror
#         T1 = 18.4
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         type = 'Switch Mirror'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m7:NXmirror
#         amp_gain = '10^3 V/A'
#         draincurrent = 4049.255510202153
#         pitch = 0.0
#           @units = 'µrad'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       name = 'XABS'
#       pgm:NXmonochromator
#         400llmmEnergyGradient = 0.98642902
#         400llmmEnergyReference = 248.0
#         400llmmGratingOffset = -0.056082
#         400llmmMirrorOffset = -0.02633
#         T1 = 16.0
#           @units = '°C'
#         cff = 2.25
#         energy = 800.0
#           @units = 'eV'
#         gratPitch = 0.0
#           @units = 'deg'
#         grating = 1200
#           @units = 'lines/mm'
#         mirrorPitch = 0.0
#           @units = 'deg'
#       s1:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s2:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s3:NXslit
#         x_centre = 0.0
#           @units = 'mm'
#         x_gap = 0.0
#           @units = 'mm'
#         x_neg = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_centre = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_neg = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s6:NXslit
#         x_gap = 0.0
#           @units = 'µm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'µm'
#         y_pos = 0.0
#           @units = 'mm'
#       source:NXsource
#         current = 250.0
#           @units = 'mA'
#         energy = 3.0
#           @units = 'GeV'
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#       t:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 't'
#         name = 't'
#         soft_limit_max = 2000000000.0
#         soft_limit_min = -2000000000.0
#         value = float64(10)
#           @gda_field_name = 't'
#           @local_name = 't.t'
#           @target = '/entry/instrument/t/value'
#           @units = 'mm'
#       xabs:NXcollection
#         amp_1_gain = 1000000000.0
#         amp_1_mode = 'low noise'
#         amp_2_gain = 100000.0
#         amp_2_mode = 'low noise'
#         pressure_sample = 3.16652e-10
#           @units = 'mbar'
#         theta = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       xbpm1:NXcollection
#         x = -0.0303253
#           @units = 'mm'
#         y = 0.0489596
#           @units = ''
#       xbpm2:NXcollection
#         x = 0.213676
#           @units = 'mm'
#         y = 0.517054
#           @units = ''
#     program_name = 'GDA 9.23.0'
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#           @units = 'mm'
#         extent = 0.0
#         flux = 0.0
#         incident_beam_divergence = 0.0
#         incident_energy = 800.0
#           @units = 'eV'
#         incident_polarization = float64(4)
#     scan_command -> /entry/diamond_scan/scan_command
#     scan_shape -> /entry/diamond_scan/scan_shape
#     start_time -> /entry/diamond_scan/start_time
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Fajin Yuan'
# === i10 ===
#
#
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   @file_name = '/scratch/gda_versions/gda-master-20211006/gda_...'
#   entry:NXentry
#     @default = 'pimte'
#     diamond_scan:NXcollection
#       duration = 4325
#         @target = '/entry/diamond_scan/duration'
#         @units = 'ms'
#       end_time = '2021-11-02T15:49:08.736'
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-11-02T15:49:04.589', '2021-11-02T15:49:04.597', '...
#       point_start_times = ['2021-11-02T15:49:04.589', '2021-11-02T15:49:04.596', '...
#       scan_command = 'scan ds 1 10 1 pimte 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 4326
#         @units = 'ms'
#       scan_dead_time_percent = 100.02312469482422
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-11-02T15:49:04.411'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       beamline = 'i10'
#       ds:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 'ds'
#         name = 'ds'
#         soft_limit_max = 1.7976931348623157e+308
#         soft_limit_min = -1.7976931348623157e+308
#         value = float64(10)
#           @gda_field_name = 'ds'
#           @local_name = 'ds.ds'
#           @target = '/entry/instrument/ds/value'
#       end_station = 'RASOR'
#       id:NXinsertion_device
#         gap = 28.881859
#           @units = 'mm'
#         harmonic = 1
#         idd:NXcollection
#           gap = 28.881859
#             @units = 'mm'
#           jawphase = 0.0
#             @units = 'mm'
#           rowphase1 = 0.0
#             @units = 'mm'
#           rowphase2 = 0.0
#             @units = 'mm'
#           rowphase3 = 0.0
#             @units = 'mm'
#           rowphase4 = 0.0
#             @units = 'mm'
#           sepphase = 0.0
#             @units = 'mm'
#         idu:NXcollection
#           gap = 28.881859
#             @units = 'mm'
#           jawphase = 0.0
#             @units = 'mm'
#           rowphase1 = 0.0
#             @units = 'mm'
#           rowphase2 = 0.0
#             @units = 'mm'
#           rowphase3 = 0.0
#             @units = 'mm'
#           rowphase4 = 0.0
#             @units = 'mm'
#           sepphase = 0.0
#             @units = 'mm'
#         polarisation = 'lv'
#         source_mode = 'idu'
#         taper = 0.0
#           @units = 'µrad'
#         type = 'undulator'
#       lakeshore340:NXsensor
#         Channel0Temp = 273.15
#           @units = 'K'
#         Channel1Temp = 273.15
#           @units = 'K'
#         Channel2Temp = 273.15
#           @units = 'K'
#         Channel3Temp = 273.15
#           @units = 'K'
#         heater = 0.4
#           @units = '%'
#         heater_range = 5
#       m1:NXmirror
#         m1_fine_pitch = 2.205559659925388
#           @units = 'V'
#         pitch = 0.0
#           @units = 'µrad'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       m3m5:NXmirror
#         m3m5_fine_pitch = 1.9154168232023894
#           @units = 'V'
#         pitch = 0.0
#           @units = 'µrad'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       m4:NXmirror
#         m4_fine_pitch = 3.7799343740480724
#           @units = 'V'
#         pitch = 0.0
#           @units = 'µrad'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       name = 'RASOR'
#       pgm:NXmonochromator
#         cff = 2.25
#         energy = 800.0
#           @units = 'eV'
#         grating = '1200 lines/mm Au'
#         grating_pitch = 88000.0
#           @units = 'mdeg'
#         grating_x = 0.0
#           @units = 'mm'
#         mirror_pitch = 88480.0
#           @units = 'mdeg'
#         mirror_x = 0.0
#           @units = 'mm'
#       pimte:NXdetector
#         count_time = float64(10)
#           @local_name = 'pimte.count_time'
#         data -> pimte-44.hdf['/entry/instrument/detector/data']
#         description = 'PIMTE - a water cold in-vacuum X-ray camera.'
#         local_name = 'pimte'
#         manufacturer = 'Simulated detector'
#         model = 'Basic simulator'
#         pimte_settings:NXcollection
#           bin_x = 1
#           bin_y = 1
#           bit_depth = 16
#           exposure = 1.0
#             @units = 's'
#           image_mode = 'Single'
#           image_size_x = 'Could not get data from ws128-AD-SIM-01:ArraySizeX_RBV :...'
#           image_size_y = 960
#           number_of_image = 1
#           period = 0.005
#             @units = 's'
#           region_size_x = 1280
#           region_size_y = 960
#           region_start_x = 0
#           region_start_y = 0
#           sensor_size_x = 1280
#           sensor_size_y = 960
#           speed = 2.0
#           temperature_measured = 25.0
#           temperature_set = 25.0
#         serial_number = '02131514'
#       rasor:NXcollection
#         aperture:NXaperture
#           downstream = 0.0
#             @units = 'mm'
#           upstream = 0.0
#             @units = 'mm'
#         cryo:NXcollection
#           x = 0.0
#             @units = 'mm'
#           y = 0.0
#             @units = 'mm'
#           z = 0.0
#             @units = 'mm'
#         diff:NXcollection
#           2_theta = 0.0
#             @units = 'deg'
#           alpha = 0.0
#             @units = 'deg'
#           chi = 0.0
#             @units = 'deg'
#           theta = 0.0
#             @units = 'deg'
#           x = 0.0
#             @units = 'mm'
#         emec:NXcollection
#           pitch = 0.0
#             @units = 'deg'
#           y1 = 0.0
#             @units = 'mm'
#           y2 = 0.0
#             @units = 'mm'
#         pin_hole:NXpinhole
#           x = 0.0
#             @units = 'mm'
#           y = 0.0
#             @units = 'mm'
#         polan:NXcollection
#           2_theta = 0.0
#             @units = 'deg'
#           eta = 0.0
#             @units = 'deg'
#           theta = 0.0
#             @units = 'deg'
#           y = 0.0
#             @units = 'mm'
#           z = 0.0
#             @units = 'mm'
#         table:NXcollection
#           back_leg = 0.0
#             @units = 'mm'
#           front_leg = 0.0
#             @units = 'mm'
#           middle_leg = 0.0
#             @units = 'mm'
#       s1:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s2:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s3:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s4:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_size = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_size = 0.0
#           @units = 'mm'
#         z = 0.0
#           @units = 'mm'
#       s5:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_hall = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         x_ring = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_minus = 0.0
#           @units = 'mm'
#         y_plus = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s6:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_hall = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         x_ring = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_minus = 0.0
#           @units = 'mm'
#         y_plus = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       source:NXsource
#         current = 250.0
#           @units = 'mA'
#         energy = 3.0
#           @units = 'GeV'
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#     pimte:NXdata
#       @axes = ['ds', '.', '.']
#       @ds_indices = 0
#       @signal = 'data'
#       data -> pimte-44.hdf['/entry/instrument/detector/data']
#       ds -> /entry/instrument/ds/value
#     program_name = 'GDA 9.23.0'
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#           @units = 'mm'
#         extent = 6.0
#         flux = 6.0
#         incident_beam_divergence = 6.0
#         incident_energy = 800.0
#           @units = 'eV'
#         incident_polarization = float64(4)
#     scan_command -> /entry/diamond_scan/scan_command
#     scan_shape -> /entry/diamond_scan/scan_shape
#     start_time -> /entry/diamond_scan/start_time
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Fajin Yuan'
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   @file_name = '/scratch/gda_versions/gda-master-20211006/gda_...'
#   entry:NXentry
#     @default = 'macj11'
#     diamond_scan:NXcollection
#       duration = 781
#         @target = '/entry/diamond_scan/duration'
#         @units = 'ms'
#       end_time = '2021-11-02T15:53:27.013'
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-11-02T15:53:26.418', '2021-11-02T15:53:26.429', '...
#       point_start_times = ['2021-11-02T15:53:26.418', '2021-11-02T15:53:26.428', '...
#       scan_command = 'scan ds 1 10 1 macj11 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 782
#         @units = 'ms'
#       scan_dead_time_percent = 100.12804412841797
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-11-02T15:53:26.232'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       beamline = 'i10'
#       ds:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 'ds'
#         name = 'ds'
#         soft_limit_max = 1.7976931348623157e+308
#         soft_limit_min = -1.7976931348623157e+308
#         value = float64(10)
#           @gda_field_name = 'ds'
# ...
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-11-02T15:56:18.943', '2021-11-02T15:56:18.950', '...
#       point_start_times = ['2021-11-02T15:56:18.943', '2021-11-02T15:56:18.950', '...
#       scan_command = 'scan ds 1 10 1 macj29 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 798
#         @units = 'ms'
#       scan_dead_time_percent = 100.1254653930664
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-11-02T15:56:18.811'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       beamline = 'i10'
#       ds:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 'ds'
#         name = 'ds'
#         soft_limit_max = 1.7976931348623157e+308
#         soft_limit_min = -1.7976931348623157e+308
#         value = float64(10)
#           @gda_field_name = 'ds'
#           @local_name = 'ds.ds'
#           @target = '/entry/instrument/ds/value'
#       end_station = 'HFM'
#       hfm:NXcollection
#         pitch = 0.0
#           @units = 'deg'
#         pitch_offset = 1.357403726690899
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       id:NXinsertion_device
#         gap = 28.881859
#           @units = 'mm'
#         harmonic = 1
#         idd:NXcollection
#           gap = 28.881859
#             @units = 'mm'
#           jawphase = 0.0
#             @units = 'mm'
#           rowphase1 = 0.0
#             @units = 'mm'
#           rowphase2 = 0.0
#             @units = 'mm'
#           rowphase3 = 0.0
#             @units = 'mm'
#           rowphase4 = 0.0
#             @units = 'mm'
#           sepphase = 0.0
#             @units = 'mm'
#         idu:NXcollection
#           gap = 28.881859
#             @units = 'mm'
#           jawphase = 0.0
#             @units = 'mm'
#           rowphase1 = 0.0
#             @units = 'mm'
#           rowphase2 = 0.0
#             @units = 'mm'
#           rowphase3 = 0.0
#             @units = 'mm'
#           rowphase4 = 0.0
#             @units = 'mm'
#           sepphase = 0.0
#             @units = 'mm'
#         polarisation = 'nc'
#         source_mode = 'idd'
#         taper = 0.0
#           @units = 'µrad'
#         type = 'undulator'
#       ips:NXcollection
#         demand_field = 0.0
#         field_set_point = 0.0
#         sweep_rate = 0.0
#       itc:NXcollection
#         sensor_temp = 0.0
#         set_point = 0.0
#       m1:NXmirror
#         m1_fine_pitch = 2.3027456766320653
#           @units = 'V'
#         pitch = 0.0
#           @units = 'µrad'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       m3m5:NXmirror
#         m3m5_fine_pitch = 1.8626216551943053
#           @units = 'V'
#         pitch = 0.0
#           @units = 'µrad'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       m6:NXmirror
#         m6_fine_pitch = 1.9332410733532546
#           @units = 'V'
#         pitch = 0.0
#           @units = 'µrad'
#         roll = 0.0
#           @units = 'µrad'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'µrad'
#         z = 0.0
#           @units = 'mm'
#       macj29:NXdetector
#         data = float64(10)
#           @target = '/entry/instrument/macj29/data'
#         description = 'Dummy Scalar Channel as Detector'
#         id = 'scalerj2 channel 9'
#         type = 'Scalar Channel Count'
#       name = 'HFM'
#       pgm:NXmonochromator
#         cff = 2.25
#         energy = 800.0
#           @units = 'eV'
#         grating = '400 lines/mm Si'
#         grating_pitch = 88000.0
#           @units = 'mdeg'
#         grating_x = 0.0
#           @units = 'mm'
#         mirror_pitch = 88480.0
#           @units = 'mdeg'
#         mirror_x = 0.0
#           @units = 'mm'
#       s1:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s2:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s3:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s7:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_size = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_size = 0.0
#           @units = 'mm'
#         z = 0.0
#           @units = 'mm'
#       s8:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_hall = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         x_ring = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_minus = 0.0
#           @units = 'mm'
#         y_plus = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s9:NXslit
#         x_hall = 0.0
#           @units = 'mm'
#         x_ring = 0.0
#           @units = 'mm'
#         y_minus = 0.0
#           @units = 'mm'
#         y_plus = 0.0
#           @units = 'mm'
#       source:NXsource
#         current = 250.0
#           @units = 'mA'
#         energy = 3.0
#           @units = 'GeV'
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#     macj29:NXdata
#       @axes = 'ds'
#       @ds_indices = 0
#       @signal = 'data'
#       data -> /entry/instrument/macj29/data
#       ds -> /entry/instrument/ds/value
#     program_name = 'GDA 9.23.0'
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#           @units = 'mm'
#         extent = 2.0
#         flux = 2.0
#         incident_beam_divergence = 2.0
#         incident_energy = 800.0
#           @units = 'eV'
#         incident_polarization = float64(4)
#     scan_command -> /entry/diamond_scan/scan_command
#     scan_shape -> /entry/diamond_scan/scan_shape
#     start_time -> /entry/diamond_scan/start_time
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Fajin Yuan'
# === i10 ===
#
#
# === Failed to create DataFrame from data - create empty DataFrame
# root:NXroot
#   @file_name = '/scratch/gda_versions/gda-master-20211006/gda_...'
#   entry:NXentry
#     @default = 'andor'
#     andor:NXdata
#       @axes = ['ds', '.', '.']
#       @ds_indices = 0
#       @signal = 'data'
#       data -> andor-16.hdf['/entry/instrument/detector/data']
#       ds -> /entry/instrument/ds/value
#     diamond_scan:NXcollection
#       duration = 230
#         @target = '/entry/diamond_scan/duration'
#         @units = 'ms'
#       end_time = '2021-11-02T16:00:08.685'
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-11-02T16:00:08.643', '2021-11-02T16:00:08.648', '...
#       point_start_times = ['2021-11-02T16:00:08.642', '2021-11-02T16:00:08.648', '...
#       scan_command = 'scan ds 1 10 1 andor 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 231
#         @units = 'ms'
#       scan_dead_time_percent = 100.43478393554688
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-11-02T16:00:08.455'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       andor:NXdetector
#         andor_settings:NXcollection
#           accumulation_period = 0.005
#             @units = 's'
#           adc_speed = '1.00 MHz'
#           binning_x = 'Could not get data from ws128-AD-SIM-01:BinX_RBV : conne...'
#           binning_y = 1
#           cooler_control = 'On'
#           cooler_status = 'Stabilized at set point'
#           cooler_temperature = -70.0
#             @units = '°C'
#           em_ccd_gain = 0.0
#           image_size_x = 'Could not get data from ws128-AD-SIM-01:ArraySizeX_RBV :...'
#           image_size_y = 960
#           preamp_gain = 1.0
#           region_size_x = 1280
#           region_size_y = 960
#           region_start_x = 0
#           region_start_y = 0
#           sensor_size_x = 1280
#           sensor_size_y = 960
#           shutter_ext_TTL = 'Close'
#           shutter_mode = 'None'
#           temperature_actual = -72.10800170898438
#             @units = '°C'
#           vertical_shift_amplitude = 0.0
#           vertical_shift_speed = '38.55 µS'
#         count_time = float64(10)
#           @local_name = 'andor.count_time'
#         data -> andor-16.hdf['/entry/instrument/detector/data']
#         description = 'Andor - an in vacuum X-ray camera.'
#         local_name = 'andor'
#         manufacturer = 'Simulated detector'
#         model = 'Basic simulator'
#       beamline = 'i21'
#       ds:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 'ds'
#         name = 'ds'
#         soft_limit_max = 1.7976931348623157e+308
#         soft_limit_min = -1.7976931348623157e+308
#         value = float64(10)
#           @gda_field_name = 'ds'
#           @local_name = 'ds.ds'
#           @target = '/entry/instrument/ds/value'
#       fast_shutter:NXpositioner
#         x = 0.0
#           @units = 'mm'
#       id:NXinsertion_device
#         bottomInner = 0.0
#           @units = 'mm'
#         bottomOuter = 0.0
#           @units = 'mm'
#         enabled = 1
#         gap = 0.0
#           @units = 'mm'
#         harmonic = 1
#         mode = 'GAP AND PHASE'
#         polarisation = 'LH'
#         rowPhase = 0.0
#           @units = 'mm'
#         taper = 0.0
#           @units = 'µrad'
#         topInner = 0.0
#           @units = 'mm'
#         topOuter = 0.0
#           @units = 'mm'
#         type = 'undulator'
#       lakeshore336:NXsensor
#         cryostat = 110.79433365185359
#           @units = 'K'
#         demand = 0.0
#           @units = 'K'
#         heater = 32.0224924847718
#           @units = '%'
#         heater_range = 0
#         sample = 180.92980556426235
#           @units = 'K'
#         shield = 204.36756766833992
#           @units = 'K'
#       m1:NXmirror
#         feedback = 0.07999999999999999
#           @units = ''
#         fine_pitch = 0.0
#           @units = 'µm'
#         fpsetpoint = 6.538478742318288
#         height = 0.0
#           @units = 'mm'
#         pitch = 0.0
#           @units = 'deg'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#       m2:NXmirror
#         feedback = 589.9000000000001
#           @units = ''
#         fine_pitch = 0.0
#           @units = 'µm'
#         fpsetpoint = 2.540279139389612
#         height = 0.0
#           @units = 'mm'
#         pitch = 0.0
#           @units = 'deg'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#       m4:NXmirror
#         femto1 = 0.9764493268131356
#         femto2 = 0.3002706320496282
#         longy = 0.0
#           @units = 'mm'
#         rx = 0.0
#           @units = 'mdeg'
#         ry = 0.0
#           @units = 'mdeg'
#         rz = 0.0
#           @units = 'mdeg'
#         x = 0.0
#           @units = 'µm'
#         y = 0.0
#           @units = 'µm'
#         z = 0.0
#           @units = 'µm'
#       m5:NXmirror
#         hqrx = 0.0
#           @units = 'mdeg'
#         hqry = 0.0
#           @units = 'mdeg'
#         hqrz = 0.0
#           @units = 'mdeg'
#         hqx = 0.0
#           @units = 'µm'
#         hqy = 0.0
#           @units = 'µm'
#         hqz = 0.0
#           @units = 'µm'
#         longy = 0.0
#           @units = 'mm'
#         lqrx = 0.0
#           @units = 'mdeg'
#         lqry = 0.0
#           @units = 'mdeg'
#         lqrz = 0.0
#           @units = 'mdeg'
#         lqx = 0.0
#           @units = 'µm'
#         lqy = 0.0
#           @units = 'µm'
#         lqz = 0.0
#           @units = 'µm'
#         tth = 0.0
#           @units = 'deg'
#       manipulator:NXcollection
#         chi = 0.0
#           @units = 'deg'
#         difftth = 0.0
#           @units = 'deg'
#         draincurrent = 0.5182843627465694
#           @units = 'V'
#         phi = 0.0
#           @units = 'deg'
#         sapara = 0.0
#         saperp = 0.0
#         th = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         z = 0.0
#           @units = 'mm'
#       name = 'i21'
#       pgm:NXmonochromator
#         b2_shadow = 8.4172
#           @units = ''
#         cff = 0.0
#         energy = 886.4
#           @units = 'eV'
#         grating_pitch = 86.809038
#           @units = 'deg'
#         grating_select = -110.0
#           @units = 'mm'
#         mirror_pitch = 87.904944
#           @units = 'deg'
#         mirror_select = -5.0
#           @units = 'mm'
#       polariser:NXcollection
#         gamma = 0.0
#           @units = 'deg'
#         stick = 0.0
#           @units = 'mm'
#       s1:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s2:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s3:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s4:NXslit
#         lower = 0.0
#           @units = 'mm'
#         nearside = 0.0
#           @units = 'mm'
#         offside = 0.0
#           @units = 'mm'
#         upper = 0.0
#           @units = 'mm'
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s5:NXslit
#         h_gap = 0.0
#           @units = 'µm'
#         hdso = 0.0
#           @units = 'µm'
#         sut = 0.0
#           @units = 'mm'
#         v1_gap = 0.0
#           @units = 'µm'
#         v2_gap = 0.0
#           @units = 'µm'
#         vdso1 = 0.0
#           @units = 'µm'
#         vdso2 = 0.0
#           @units = 'µm'
#       s6:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       sgm:NXcollection
#         grating_select = 'SVLS1'
#         h = 0.0
#           @units = 'mm'
#         pitch = 0.0
#           @units = 'deg'
#         r1 = 0.0
#           @units = 'mm'
#         wedge_nearside = 0.0
#           @units = 'mm'
#         wedge_offside = 0.0
#           @units = 'mm'
#         x = 0.0
#           @units = 'mm'
#       source:NXsource
#         current = 250.0
#           @units = 'mA'
#         energy = 3.0
#           @units = 'GeV'
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#       spectrometer:NXcollection
#         armtth = 0.0
#           @units = 'deg'
#         specgamma = 0.0
#           @units = 'deg'
#         spech = 0.0
#           @units = 'mm'
#         specl = 0.0
#           @units = 'mm'
#     program_name = 'GDA 9.23.0'
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#           @units = 'mm'
#         extent = 10.0
#         flux = 10.0
#         incident_beam_divergence = 10.0
#         incident_energy = 886.4
#           @units = 'eV'
#         incident_polarization = float64(4)
#     scan_command -> /entry/diamond_scan/scan_command
#     scan_shape -> /entry/diamond_scan/scan_shape
#     start_time -> /entry/diamond_scan/start_time
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Fajin Yuan'

# %%
n = pdnx(pi06 % 28)
# Out:
# === Failed to create DataFrame from data - create empty DataFrame

# %%
n.find('keys')
# Out:
# .nx.entry.diamond_scan.keys : 	 keys

# %%
print(n.nx.entry.diamond_scan['keys'])
# Out:
# keys
