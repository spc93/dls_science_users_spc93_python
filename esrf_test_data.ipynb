# %%
#Python 3.7 [DLS conda]

import sys
#sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

#%matplotlib inline
# %matplotlib notebook
mysample_0003 = '/home/spc93/misc_nexus_data/ESRF/mysample_0003/mysample_0003.h5'
cifpath = '/home/spc93/spc_cifs/'
# Out:
# === Importing dlstools package

# %%
n = pdnx(mysample_0003)
# Out:
# === Failed to create DataFrame from data - create empty DataFrame

# %%
n.pruned_tree(3)
# Out:
# .1.1
# .1.1.end_time
# .1.1.instrument
# .1.1.instrument.diode1
# .1.1.instrument.elapsed_time
# .1.1.instrument.epoch
# .1.1.instrument.lima_simulator
# .1.1.instrument.mca1_det0
# .1.1.instrument.mca1_det1
# .1.1.instrument.mca1_det2
# .1.1.instrument.mca1_det3
# .1.1.instrument.positioners
# .1.1.instrument.positioners_dial_end
# .1.1.instrument.positioners_dial_start
# .1.1.instrument.positioners_end
# .1.1.instrument.positioners_start
# .1.1.instrument.roby
# .1.1.instrument.secondary_slits
# .1.1.instrument.title
# .1.1.instrument.transfocator
# .1.1.measurement
# .1.1.measurement.diode1
# .1.1.measurement.elapsed_time
# .1.1.measurement.epoch
# .1.1.measurement.lima_simulator
# .1.1.measurement.mca1_det0
# .1.1.measurement.mca1_det0_elapsed_time
# .1.1.measurement.mca1_det0_event_count_rate
# .1.1.measurement.mca1_det0_events
# .1.1.measurement.mca1_det0_fractional_dead_time
# .1.1.measurement.mca1_det0_live_time
# .1.1.measurement.mca1_det0_trigger_count_rate
# ...

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   @HDF5_Version = '1.10.6'
#   @creator = 'Bliss'
#   @creator_version = '1.9.0+60-g86b95f05f'
#   @default = '1.1'
#   @file_name = '/tmp/scans/inhouse/id002110/id00/mysample/mysa...'
#   @file_time = '2021-10-29T16:19:40.934511+02:00'
#   @h5py_version = '3.3.0'
#   @publisher_version = '1.9.0+60-g86b95f05f'
#   1.1:NXentry
#     @default = 'plotselect'
#     end_time = '2021-10-29T16:19:42.472446+02:00'
#     instrument:NXinstrument
#       diode1:NXdetector
#         data = float64(11)
#         mode = 'MEAN'
#         type = 'samplingcounter'
#       elapsed_time:NXdetector
#         data = float64(11)
#           @units = 's'
#       epoch:NXdetector
#         data = float64(11)
#           @units = 's'
#       lima_simulator:NXdetector
#         acq_parameters:NXcollection
#           acq_expo_time = 0.01
#           acq_mode = 'SINGLE'
#           acq_nb_frames = 11
#           acq_trigger_mode = 'INTERNAL_TRIGGER_MULTI'
#           latency_time = 0
# ...

# %%
n.nx.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/nexusformat/nexus/tree.py in __getattr__(self, name)
#    5059         try:
# -> 5060             return getattr(self.nxlink, name)
#    5061         except Exception as error:
#
# ~/.local/lib/python3.7/site-packages/nexusformat/nexus/tree.py in __getattr__(self, name)
#    2725         else:
# -> 2726             raise AttributeError("'"+name+"' not in "+self.nxpath)
#    2727
#
# AttributeError: 'units' not in /1.1/instrument/diode1/data
#
# During handling of the above exception, another exception occurred:
#
# NeXusError                                Traceback (most recent call last)
# <ipython-input-5-98590cfed531> in <module>
# ----> 1 n.nx.plot()
#
# ~/.local/lib/python3.7/site-packages/nexusformat/nexus/tree.py in plot(self, **kwargs)
#    4882         plotdata = self.plottable_data
# ...

# %%
#pip install watermark
# %load_ext watermark
# %watermark -v -m -p wget,pandas,numpy
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.7.3
# IPython version      : 7.5.0
#
# wget  : not installed
# pandas: 0.24.2
# numpy : 1.18.1
#
# Compiler    : GCC 7.3.0
# OS          : Linux
# Release     : 3.10.0-1160.36.2.el7.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 48
# Architecture: 64bit

# %%
# %watermark
# Out:
# Last updated: 2021-11-01T15:12:54.752551+00:00
#
# Python implementation: CPython
# Python version       : 3.7.3
# IPython version      : 7.5.0
#
# Compiler    : GCC 7.3.0
# OS          : Linux
# Release     : 3.10.0-1160.36.2.el7.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 48
# Architecture: 64bit

# %%
watermark?
