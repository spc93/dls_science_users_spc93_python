# %%
import pandas as pd
pd.set_option('display.max_rows',9999)
#%run TensorScatteringClass # test class
import TensorScatteringClass as ten
import numpy as np
from IPython.display import display

# %%
sg_no = 13
t=ten.TensorScatteringClass(spacegroup_number = sg_no)
_tol = 1e-12
for wyckoff in t.all_letters:
    t=ten.TensorScatteringClass(spacegroup_number = sg_no, wyckoff_letter = wyckoff)

    print('\nForbidden reflections (site %s):\n' % wyckoff)
    for h in range(5):
        for k in range(5):
            for l in range(5):

                hkl=np.array([h, k, l])
                _out = t.SF_symmetry(t.sitevec, hkl, t.sglist)
                #print(h, k, l, np.abs(t.siteSF))
                if np.abs(t.siteSF) < _tol:
                    print(h, k, l)
# Out:
# Crystal properties
#
#                     CIF file:  Spacegroup # 13
#                      Lattice:  0.500 0.500 0.500 90.00 90.00 90.00
#                    All sites:
#                Site selected:  2 a
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  4
#       No. of sym ops at site:  2
#  No. of equiv. sites in cell:  2
#    No. of pg ops for crystal:  4
#
# Crystal properties
#
#                     CIF file:  Spacegroup # 13
#                      Lattice:  0.500 0.500 0.500 90.00 90.00 90.00
#                    All sites:
#                Site selected:  4 g
#                  Site vector:  0.689 0.371 0.333
#        No. of spacegroup ops:  4
#       No. of sym ops at site:  1
#  No. of equiv. sites in cell:  4
#    No. of pg ops for crystal:  4
#
# Forbidden reflections (site g):
#
# 0 0 1
# 0 0 3
# 1 0 1
# 1 0 3
# 2 0 1
# 2 0 3
# 3 0 1
# 3 0 3
# 4 0 1
# 4 0 3
#
# Crystal properties
#
#                     CIF file:  Spacegroup # 13
# ...

# %%
# calculate SF for h, k, l
# look for patterns - reflection conditions? 

# work out possible linear combinations of hkl and possible restrictions on them - then check numerically

# upload tensor scattering class to github

# %%
import cctbx

# %%
pip install cctbx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement cctbx
# ERROR: No matching distribution found for cctbx
# Note: you may need to restart the kernel to use updated packages.

# %%
import cctbx.sgtbx

# %%
pip install cctbx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement cctbx
# ERROR: No matching distribution found for cctbx
# Note: you may need to restart the kernel to use updated packages.
