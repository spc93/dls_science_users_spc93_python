# %% [raw]
# Look at 010 E1E2

# %%
import TensorScatteringClass as ten
import numpy as np
cifpath = '/home/spc93/spc_cifs/'
ciffile=cifpath+'FeLiAs_P4nmm_icsd_42331_cifbib.cif'
en = FeK = 7.11
t=ten.TensorScatteringClass(CIFfile=ciffile, Site='Fe1');

#non-resonant magnetic scattering and resonant scattering 


t.PlotIntensityInPolarizationChannels('E1E2', lam=12.4/en, hkl = np.array([0,1,0]), hkln = np.array([1,0,0]) , K=3, Time=1, Parity=-1, sigmapi='sigma'); print('=== tth: %.2f deg' % (t.theta * 2 *180./np.pi))
t.print_tensors()
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/FeLiAs_P4nmm_icsd_42331_cifbib.cif
#                      Lattice:  3.776 3.776 6.349 90.00 90.00 90.00
#                    All sites:  Fe1, Li1, As1, Li2
#                Site selected:  Fe1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  16
#       No. of sym ops at site:  8
#  No. of equiv. sites in cell:  2
#    No. of pg ops for crystal:  16
#
# Tensor properties
#
#              Required parity:  Odd
#           Required time sym.:  Even
#                          hkl:  [0.0, 1.0, 0.0]
#                 Site allowed:  No
#    Structure factor for site:  0.00+0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
#               Glide or screw:  True
# === tth: 26.70 deg
#
# Tensor components
#
# ...

# %%
# %matplotlib notebook
import sys, os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append('/dls_sw/i16/software/python/userscripts/i16user/Dans_Diffraction')
import Dans_Diffraction as dif

#cif_file = '/dls_sw/i16/software/python/Dans_Diffraction/Dans_Diffraction/Structures/Diamond.cif' 

#cifpath = '/home/spc93/spc_cifs/'
#cif_file=cifpath+'MnF2.cif'
FeK = 7.112

xtl = dif.Crystal(ciffile)
print(xtl)
# Out:
# ###########################################
# FeLiAs_P4nmm_icsd_42331_cifbib
# Formula: Li1.1FeS
# Magnetic: False
# a =  3.776 A,  b =  3.776 A,  c =  6.349 A
# A =    90.00,  B =    90.00,  G =    90.00
# Volume:  90.53 A^3
#
# Density:  3.505 g/cm
#   n Label Atom  u       v       w        Occ  Uiso
#   0   Fe1   Fe  0.0000  0.0000  0.0000   1.00 0.0000
#   1   Fe1   Fe  0.5000  0.5000  0.0000   1.00 0.0000
#   2   Li1   Li  0.5000  0.0000  0.7600   1.00 0.0000
#   3   Li1   Li  0.0000  0.5000  0.2400   1.00 0.0000
#   4   As1    S  0.5000  0.0000  0.2400   1.00 0.0000
#   5   As1    S  0.0000  0.5000  0.7600   1.00 0.0000
#   6   Li2   Li  0.0000  0.0000  0.5000   0.10 0.0000
#   7   Li2   Li  0.5000  0.5000  0.5000   0.10 0.0000

# %% [raw]
# # Multiple Scattering - single azimuth
# azimuth, intensity = xtl.Scatter.ms_azimuth([5,0,0], energy_kev=MnK)
#
# plt.figure()
# plt.plot(azimuth, intensity, '-', lw=2, label='(5,0,0)')
# plt.xlabel('azimuth [Deg]')
# plt.ylabel('Intensity')

# %%
# Plot multipel scattering energy/ azimuth 
# see help(xtl.Scatter.multiple_scattering))
mslist = xtl.Plot.plot_multiple_scattering(
    hkl=[0,1,0], 
    azir=[0,0,1], 
    pv=[1, 0], 
    energy_range=[FeK-.1, FeK+.05], 
    numsteps=101,
    full=False, 
    pv1=False, 
    pv2=False, 
    sfonly=True, 
    pv1xsf1=False
)
# Out:
# MS Reflections: 602
# 1 of 101
# 2 of 101
# 3 of 101
# 4 of 101
# 5 of 101
# 6 of 101
# 7 of 101
# 8 of 101
# 9 of 101
# 10 of 101
# 11 of 101
# 12 of 101
# 13 of 101
# 14 of 101
# 15 of 101
# 16 of 101
# 17 of 101
# 18 of 101
# 19 of 101
# 20 of 101
# 21 of 101
# 22 of 101
# 23 of 101
# 24 of 101
# 25 of 101
# 26 of 101
# 27 of 101
# 28 of 101
# 29 of 101
# 30 of 101
# 31 of 101
# 32 of 101
# 33 of 101
# 34 of 101
# 35 of 101
# 36 of 101
# 37 of 101
# 38 of 101
# 39 of 101
# 40 of 101
# 41 of 101
# 42 of 101
# 43 of 101
# 44 of 101
# 45 of 101
# 46 of 101
# 47 of 101
# 48 of 101
# 49 of 101
# 50 of 101
# 51 of 101
# 52 of 101
# 53 of 101
# 54 of 101
# 55 of 101
# 56 of 101
# 57 of 101
# 58 of 101
# 59 of 101
# 60 of 101
# 61 of 101
# 62 of 101
# 63 of 101
# 64 of 101
# 65 of 101
# 66 of 101
# 67 of 101
# 68 of 101
# 69 of 101
# 70 of 101
# 71 of 101
# 72 of 101
# 73 of 101
# 74 of 101
# 75 of 101
# 76 of 101
# 77 of 101
# 78 of 101
# 79 of 101
# 80 of 101
# 81 of 101
# 82 of 101
# ...
