# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
cifpath='/home/spc93/spc_cifs/'

from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *

#from dlstools.quickfit import *
import matplotlib.pyplot as plt

import TensorScatteringClass as ten

#%matplotlib inline
# %matplotlib notebook
#%matplotlib nbagg

#p='/dls/i16/data/2022/cm31138-6/%i.nxs'
p='/dls/i16/data/2023/mm33190-1/%i.nxs'
# Out:
# === Importing dlstools package

# %% [raw]
# #/dls_sw/i16/scripts/Users/steve/
#
# #run('/dls_sw/i16/scripts/Users/steve/pol_scannable_test.py')
#
# def trace2(array2):
#     # trace of 2x2 array
#     return (array2[0, 0] + array2[1, 1])
#
# def dot(A, B):
#     # dnp dot method fails with complex arrays
#     Ar, Aim, Br, Bim = dnp.real(A), np.imag(A), np.real(B), np.imag(B)
#     return dnp.dot(Ar, Br) - dnp.dot(Aim, Bim) + 1.J * dnp.dot(Ar, Bim) + 1.J * dnp.dot(Aim, Br)
#
# class polarizer(ScannableMotionBase):
#     '''
#     self.set_scatter_type - set scatter type; self.set_scatter_type('') to see options
#     set_mag_vec - set magnetic vector to list/array
#     returns:
#         JA[0,0], JA[1,0], JA[0,1], JA[1,1]  - Polarization analyser Jones matrix components
#         Idirect, Itot, Ipol                 - Direct beam intensity through analyser, total intensity from sample, polarization analyer intensity from sample
#     '''
#
#     def __init__(self,name):
#         self.setName(name)
#         self.setLevel(7)
#         self.scatter_type = 'charge'    # default scattering mechanism
#         self.setInputNames([])
#         self.setExtraNames(['J00', 'J01', 'J10', 'J11', 'Idirect', 'Itot_' + self.scatter_type, 'Ipol_' + self.scatter_type])
#         self.setOutputFormat(['%.4f','%.4f','%.4f','%.4f','%.3f', '%.3f', '%.3f'])
#         self.m1, self.m2, self.m3 = 0., 0., 1.
#
#
#     def set_scatter_type(self, scatter_type):
#         scatter_types = ['charge', 'magE1E1', 'magSpin'] # scattering mechanism
#         if scatter_type in scatter_types:
#           self.scatter_type = scatter_type
#         else:
#           print('=== scatter type must be one of: ', scatter_types)
#         print('Scatter type is: ', self.scatter_type)
#         self.setExtraNames(['J00', 'J01', 'J10', 'J11', 'Idirect', 'Itot_' + self.scatter_type, 'Ipol_' + self.scatter_type])
#
#     def set_mag_vec(self, magvec):
#         [self.m1, self.m2, self.m3] =  magvec
#
#     def BB(self, q, q1, e, e1):  # spin scattering vector
#         return dnp.cross(e1, e) + dnp.cross(q1, e1)*dnp.dot(q1, e) - dnp.cross(q, e)*dnp.dot(q, e1) - dnp.cross(dnp.cross(q1, e1),dnp.cross(q, e))
#
#
#     def getPosition(self):
#         # get motor positions
#         xi_deg = stokes()
#         #tthp_deg = 2 * thp() #assume thp is correct; tthp may be offset
#         tthp_deg = 2 * 180.0 / dnp.pi * dnp.arcsin( 6.2 * pol.getCrystal()[2] / pol.getCrystal()[1] / en()) # get tthp from pol and en
#         gamma_deg = gam()
#         delta_deg = delta()
#
#         P1, P2, P3 = 1., 0., 0.
#         _mu = dnp.array([[P1/2. + 1/2., P2/2. - 1J*P3/2.], [P2/2. + 1J*P3/2., 1/2. - P1/2.]])
#
#
#         xi_rad, tthp_rad, gamma_rad, delta_rad = xi_deg * dnp.pi/180, tthp_deg * dnp.pi/180, gamma_deg * dnp.pi/180, delta_deg * dnp.pi/180
#
#         # calculate J and Icharge
#
#         self.JA = dnp.array([[dnp.cos(xi_rad), -dnp.sin(xi_rad)], [dnp.sin(xi_rad)*np.cos(tthp_rad), np.cos(tthp_rad)*np.cos(xi_rad)]])
#
#         Rgammadelta = dnp.array([[dnp.cos(gamma_rad), -dnp.sin(delta_rad)*dnp.sin(gamma_rad), dnp.sin(gamma_rad)*dnp.cos(delta_rad)],
#                                 [0., dnp.cos(delta_rad), dnp.sin(delta_rad)],
#                                 [-dnp.sin(gamma_rad), -dnp.sin(delta_rad)*dnp.cos(gamma_rad), dnp.cos(delta_rad)*dnp.cos(gamma_rad)]])
#
#         x, y, z = dnp.array([1., 0., 0.]), dnp.array([0., 1., 0.]), dnp.array([0., 0., 1.])
#         x1, y1, z1 = dnp.dot(Rgammadelta,x), dnp.dot(Rgammadelta,y), dnp.dot(Rgammadelta,z)
#
#         U3 = (z - z1) / dnp.linalg.norm(z - z1)
#         U1 = (z + z1) / dnp.linalg.norm(z + z1)
#         U2 = dnp.cross(U3, U1)
#
#         m = self.m1 * U1 + self.m2 * U2 + self.m3 * U3
#
#         if self.scatter_type == 'charge':
#             self.J = dnp.array([[dnp.cos(gamma_rad), 0], [-dnp.sin(delta_rad)*dnp.sin(gamma_rad), dnp.cos(delta_rad)]])
#         elif self.scatter_type == 'magE1E1':
#             self.J =  dnp.array([
#               [-m[1] * dnp.sin(gamma_rad), m[0] * dnp.sin(gamma_rad) + m[2] * dnp.cos(gamma_rad)],
#               [-m[1] * dnp.sin(delta_rad)*dnp.cos(gamma_rad) - m[2] * dnp.cos(delta_rad), m[0] * dnp.sin(delta_rad)*dnp.cos(gamma_rad) - m[2] * dnp.sin(delta_rad)*dnp.sin(gamma_rad)]])
#         elif self.scatter_type == 'magSpin':
#             self.J =  dnp.array([
#                 [dnp.dot(m, self.BB(z, z1, x, x1)), dnp.dot(m, self.BB(z, z1, y, x1))],
#                 [dnp.dot(m, self.BB(z, z1, x, y1)), dnp.dot(m, self.BB(z, z1, y, y1))]
#             ])
#         else:
#             raise('Scatter type', self.scatter_type, ' not supported')
#
#
#
#
#         self.Itot = trace2(dot(self.J, dot(_mu, dnp.conjugate(self.J).T)))
#         #result should be real but convert to allow scan
#         self.Itot =  float(dnp.real(self.Itot))
#
#
#         self.Ipol = trace2(dot(self.JA, dot(self.J, dot(_mu, dot(dnp.conjugate(self.J).T, dnp.conjugate(self.JA).T)))))
#         #result should be real but convert to allow scan
#         self.Ipol =  float(dnp.real(self.Ipol))
#
#         self.Idirect = trace2(dot(self.JA, dot(_mu, dnp.conjugate(self.JA).T)))
#         #result should be real but convert to allow scan
#         self.Idirect =  float(dnp.real(self.Idirect))
#
#
#         return [self.JA[0,0], self.JA[1,0], self.JA[0,1], self.JA[1,1], self.Idirect, self.Itot, self.Ipol]
#
#     def isBusy(self):
#         return 0
#
#
# class mag_zrot(ScannableMotionBase):
#     '''
#     to rotate magnetic moment about z axis
#     '''
#
#     def __init__(self,name):
#         self.setName(name)
#         self.setLevel(6)
#         self.setInputNames(['zrot'])
#         self.setOutputFormat(['%.1f'])
#         self.m1, self.m2, self.m3 = 1., 0., 0. # magnetic vector with no rotation
#         self.zrot = 0.0
#
#
#     def set_mag_vec(self, magvec):  #magnetic vector with no rotation
#         [self.m1, self.m2, self.m3] =  magvec
#
#     def getPosition(self):
#         return [self.zrot]
#
#     def asynchronousMoveTo(self, zrot):
#         self.zrot = zrot
#         c, s = cos(zrot * dnp.pi/180), sin(zrot * dnp.pi/180)
#         pp.set_mag_vec([self.m1 * c - self.m2 * s, self.m1 * s + self.m2 * c, self.m3]) # set mag vector in pp device
#
#     def isBusy(self):
#         return 0
#
# zrot = mag_zrot('zrot')
#
#
# #error in this:
# #dnp.trace(dnp.matmul(ss.JA, dnp.matmul(ss.JC, dnp.matmul(mu, dnp.matmul(dnp.conjugate(ss.JC).T, dnp.conjugate(ss.JA).T)))))
#
# #'/dls/i16/data/2023/mm33190-1'
# # 1007372-76
#
# pp = polarizer('I16 PA')
# pp
#
# # pp.set_scatter_type('charge')
# # scan stokes 0 90 5 pp
# #
# # pp.set_scatter_type('magE1E1')
# # pp.set_mag_vec([1., 0., 0])
# # scan stokes 90 0 5 pp
# #
# # pp.set_mag_vec([0., 1., 0])
# # scan stokes 0 90 5 pp
# #
# # pp.set_scatter_type('magSpin')
# # pp.set_mag_vec([1., 0., 0])
# # scan stokes 90 0 5 pp
# #
# # pp.set_mag_vec([0., 1., 0])
# # scan stokes 0 90 5 pp
#
# # 385-6
# # pos stokes 0
# # pp.set_scatter_type('magSpin')
# # scan zrot 0 360 5 pp
# #
# # pos stokes 90
# # pp.set_scatter_type('magSpin')
# # scan zrot 0 360 5 pp
#
# # 387-390
# # pos zrot 45
# # pp.set_scatter_type('magSpin')
# # scan stokes 0 90 5 pp
# #
# # pos zrot -45
# # pp.set_scatter_type('magSpin')
# # scan stokes 90 0 5 pp
#
# # pos zrot 180+45
# # pp.set_scatter_type('magSpin')
# # scan stokes 0 90 5 pp
# #
# # pos zrot 180-45
# # pp.set_scatter_type('magSpin')
# # scan stokes 90 0 5 pp

# %%
#tthp ~ 70 deg
#delta = 40 deg
c = 14.963 # use 009
lam = 2 * (c/9) *np.sin(np.pi/180 * 20)
lam
# Out:
# 1.1372549787959958

# %%
# %matplotlib notebook

# charge scattering
# plot tensorscatteringclass simulation and superimpose results from scannable
#n.plot('stokes', 'Ipol_charge')

ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');

t.PlotIntensityVsPolarizationAnalyserRotation('Scalar', lam = lam, hkl = np.array([0,0,6]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), pol_th_deg = 35, K=None, Time=None, Parity=None, mk=None, lk=np.array([.0,0,0]), sk=np.array([.1,0,0]) , savefile=None)

n = pdnx(p % 1007372)
plot(n.stokes, n.Ipol_charge, '.')
plt.ylim([0, 1])
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">
# (0, 1)

# %%
# magE1E1 scattering
# plot tensorscatteringclass simulation and superimpose results from scannable
#n.plot('stokes', 'Ipol_charge')

#pp.set_mag_vec([1., 0., 0])

ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityVsPolarizationAnalyserRotation('E1E1mag', lam = lam, hkl = np.array([0,0,6]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), pol_th_deg = 35, K=None, Time=None, Parity=None, mk=np.array([1,0,0]), savefile=None)

n = pdnx(p % 1007373)
plot(n.stokes, n.Ipol_magE1E1, '.')
plt.ylim([0, 1])

#pp.set_mag_vec([0., 1., 0])

ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityVsPolarizationAnalyserRotation('E1E1mag', lam = lam, hkl = np.array([0,0,6]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), pol_th_deg = 35, K=None, Time=None, Parity=None, mk=np.array([0,1,0]), savefile=None)

n = pdnx(p % 1007374)
plot(n.stokes, n.Ipol_magE1E1, '.')
plt.ylim([0, 1])
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
# NonResMag scattering
# plot tensorscatteringclass simulation and superimpose results from scannable
#n.plot('stokes', 'Ipol_charge')

#pp.set_mag_vec([1., 0., 0])

ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityVsPolarizationAnalyserRotation('NonResMag', lam = lam, hkl = np.array([0,0,6]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), pol_th_deg = 35, K=None, Time=None, Parity=None, sk=np.array([1,0,0]), lk=np.array([0,0,0]), savefile=None)

n = pdnx(p % 1007375)
plot(n.stokes, n.Ipol_magSpin, '.')
plt.ylim([0, 1])
#pp.set_mag_vec([0., 1., 0])

ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityVsPolarizationAnalyserRotation('NonResMag', lam = lam, hkl = np.array([0,0,6]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), pol_th_deg = 35, K=None, Time=None, Parity=None, sk=np.array([0,1,0]), lk=np.array([0,0,0]), savefile=None)

n = pdnx(p % 1007376)
plot(n.stokes, n.Ipol_magSpin, '.')
plt.ylim([0, 1])
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityInPolarizationChannelsVsMagrot('NonResMag', lam=lam, hkl=np.array([0,0,9]), hkln=np.array([1,0,0]), psideg=0, lk=np.array([0,0,0]), sk=np.array([1,0,0]), sigmapi='sigma')
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">

# %%
# 385-6
# pos stokes 0
# pp.set_scatter_type('magSpin')
# scan zrot 0 360 5 pp
#
# pos stokes 90
# pp.set_scatter_type('magSpin')
# scan zrot 0 360 5 pp

figure()
n = pdnx(p % 1007385)
plot(n.zrot, n.Ipol_magSpin)
n = pdnx(p % 1007386)
plot(n.zrot, n.Ipol_magSpin, '.')

### stokes 90 - almost flat. tensor calc shows more variation but different thp (45 deg cf 35 deg). Is this OK?
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 387-390
# pos zrot 45
# pp.set_scatter_type('magSpin')
# scan stokes 0 90 5 pp
#
# pos zrot -45
# pp.set_scatter_type('magSpin')
# scan stokes 90 0 5 pp

# pos zrot 180+45
# pp.set_scatter_type('magSpin')
# scan stokes 0 90 5 pp
#
# pos zrot 180-45
# pp.set_scatter_type('magSpin')
# scan stokes 90 0 5 pp

figure()
n = pdnx(p % 1007387)
plot(n.stokes, n.Ipol_magSpin, '.')
n = pdnx(p % 1007388)
plot(n.stokes, n.Ipol_magSpin, 'o')
n = pdnx(p % 1007389)
plot(n.stokes, n.Ipol_magSpin)
n = pdnx(p % 1007390)
plot(n.stokes, n.Ipol_magSpin)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
t.lattice
# Out:
# [4.6618, 4.6618, 14.963, 90.0, 90.0, 120.0]

# %%
t.theta  * 180/np.pi
# Out:
# 20.000000000000004

# %%
# simulations for SR school slides

import TensorScatteringClass as ten
import numpy as np
cifpath='/home/spc93/spc_cifs/'
lam = 12.4/7.7

ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityInPolarizationChannelsVsMagrot('NonResMag', lam=lam, hkl=np.array([0,0,9]), hkln=np.array([1,0,0]), psideg=0, lk=np.array([0,0,0]), sk=np.array([1,0,0]), sigmapi='sigma')

ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityVsPolarizationAnalyserRotation('Scalar', lam = lam, hkl = np.array([0,0,6]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), pol_th_deg = 35, K=None, Time=None, Parity=None, savefile=None)

#sk = 100 (along beam; magnet perp to beam) - check this!
ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityVsPolarizationAnalyserRotation('NonResMag', lam = lam, hkl = np.array([0,0,9]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), pol_th_deg = 35, K=None, Time=None, Parity=None, sk=np.array([1,0,0]), lk=np.array([0,0,0]), savefile=None)

#sk = 010 (perp to beam; magnet along beam) - check this!
ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityVsPolarizationAnalyserRotation('NonResMag', lam = lam, hkl = np.array([0,0,9]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), pol_th_deg = 35, K=None, Time=None, Parity=None, sk=np.array([0,1,0]), lk=np.array([0,0,0]), savefile=None)
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">
# ...
