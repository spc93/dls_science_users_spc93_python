# %%
#Python 3.7 [DLS conda]

import sys
#sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

#%matplotlib inline
# %matplotlib notebook
p = '/home/spc93/misc_nexus_data/i06/i06-%i.nxs'
cifpath = '/home/spc93/spc_cifs/'

#files: 7, 23, 332
# Out:
# === Importing dlstools package

# %%
n = pdnx(p % 23)
# Out:
# === Failed to create DataFrame from data - create empty DataFrame

# %%
n.pruned_tree(3)
# Out:
# .entry
# .entry.diamond_scan
# .entry.diamond_scan.duration
# .entry.diamond_scan.end_time
# .entry.diamond_scan.keys
# .entry.diamond_scan.point_end_times
# .entry.diamond_scan.point_start_times
# .entry.diamond_scan.scan_command
# .entry.diamond_scan.scan_dead_time
# .entry.diamond_scan.scan_dead_time_percent
# .entry.diamond_scan.scan_estimated_duration
# .entry.diamond_scan.scan_finished
# .entry.diamond_scan.scan_rank
# .entry.diamond_scan.scan_shape
# .entry.diamond_scan.start_time
# .entry.duration
# .entry.end_time
# .entry.instrument
# .entry.instrument.EC1
# .entry.instrument.OH1
# .entry.instrument.beamline
# .entry.instrument.d4
# .entry.instrument.d5
# .entry.instrument.d6
# .entry.instrument.d7
# .entry.instrument.d7a
# .entry.instrument.end_station
# .entry.instrument.id
# .entry.instrument.leem
# .entry.instrument.m1
# .entry.instrument.m3
# .entry.instrument.m4
# .entry.instrument.m5
# .entry.instrument.m6
# .entry.instrument.medipix
# .entry.instrument.name
# .entry.instrument.pgm
# .entry.instrument.ps
# .entry.instrument.s1
# .entry.instrument.s2
# .entry.instrument.s3
# .entry.instrument.s4
# .entry.instrument.s5
# .entry.instrument.source
# .entry.instrument.t
# .entry.instrument.xbpm1
# .entry.instrument.xbpm2
# .entry.medipix
# .entry.medipix.data
# .entry.medipix.t
# .entry.program_name
# .entry.sample
# .entry.sample.beam
# .entry.scan_command
# .entry.scan_shape
# .entry.start_time
# .entry.user01
# .entry.user01.facility_user_id
# .entry.user01.name

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   @file_name = '/scratch/gda_versions/gda-master-20211006/gda_...'
#   entry:NXentry
#     @default = 'medipix'
#     diamond_scan:NXcollection
#       duration = 4734
#         @target = '/entry/diamond_scan/duration'
#         @units = 'ms'
#       end_time = '2021-10-29T10:12:59.834'
#         @target = '/entry/diamond_scan/end_time'
#       keys:NXcollection
#         uniqueKeys = int32(10)
#       point_end_times = ['2021-10-29T10:12:55.276', '2021-10-29T10:12:55.281', '...
#       point_start_times = ['2021-10-29T10:12:55.275', '2021-10-29T10:12:55.280', '...
#       scan_command = 'scan t 1 10 1 medipix 1'
#         @target = '/entry/diamond_scan/scan_command'
#       scan_dead_time = 4735
#         @units = 'ms'
#       scan_dead_time_percent = 100.02112579345703
#       scan_estimated_duration = -1
#         @units = 'ms'
#       scan_finished = 1
#       scan_rank = 1
#       scan_shape = 10
#         @target = '/entry/diamond_scan/scan_shape'
#       start_time = '2021-10-29T10:12:55.100'
#         @target = '/entry/diamond_scan/start_time'
#     duration -> /entry/diamond_scan/duration
#     end_time -> /entry/diamond_scan/end_time
#     instrument:NXinstrument
#       EC1:NXcollection
#         temperature = 21.98
#           @units = '°C'
#       OH1:NXcollection
#         temperature = 22.2
#           @units = '°C'
#       beamline = 'i06'
#       d4:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d5:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d6:NXcollection
#         y = 0.0
#           @units = 'mm'
#       d7:NXcollection
#         x = 0.0
#           @units = 'mm'
#       d7a:NXcollection
#         x = 0.0
#           @units = 'mm'
#       end_station = 'PEEM'
#       id:NXinsertion_device
#         gap = 0.0
#           @units = 'mm'
#         harmonic = 1
#         idd:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         idu:NXcollection
#           brp = 0.0
#             @units = 'mm'
#           gap = 0.0
#             @units = 'mm'
#           la_angle = 0.0
#             @units = 'deg'
#           trp = 0.0
#             @units = 'mm'
#         polarisation = 'nc'
#         pugap = 0.0
#           @units = 'mm'
#         source_mode = 'idd'
#         taper = 0.0
#           @units = 'µrad'
#         type = 'undulator'
#       leem:NXcollection
#         fov = 5.0
#         obj = 1.0
#         objStigmA = 3.0
#         objStigmB = 4.0
#         rot = 0.0
#           @units = 'deg'
#         stv = 2.5
#       m1:NXmirror
#         T1 = 17.2
#           @units = '°C'
#         T2 = 14.5
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m3:NXmirror
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       m4:NXmirror
#         pitch = 0.0
#           @units = 'deg'
#         roll = 0.0
#           @units = 'deg'
#       m5:NXmirror
#         bend1 = 0.0
#           @units = 'deg'
#         bend2 = 0.0
#           @units = 'deg'
#         pitch = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         x1 = 0.0
#           @units = 'mm'
#         x2 = 0.0
#           @units = 'mm'
#       m6:NXmirror
#         T1 = 18.4
#           @units = '°C'
#         pitch = 0.0
#           @units = 'deg'
#         qg = 0.0
#           @units = 'V'
#         roll = 0.0
#           @units = 'deg'
#         type = 'Switch Mirror'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#         yaw = 0.0
#           @units = 'deg'
#         z = 0.0
#           @units = 'mm'
#       medipix:NXdetector
#         count_time = float64(10)
#           @local_name = 'medipix.count_time'
#         data -> medipix-23.hdf['/entry/instrument/detector/data']
#         description = 'MediPix - a water cold X-ray camera.'
#         local_name = 'medipix'
#         manufacturer = 'Simulated detector'
#         medipix_settings:NXcollection
#           bit_depth = 24
#           configuration_file = 'BL06I-EA-DET-02:CAM:FullFileName_RBV'
#           configuration_file_name = 'BL06I-EA-DET-02:CAM:FileName_RBV'
#           configuration_file_path = 'BL06I-EA-DET-02:CAM:FilePath_RBV'
#           equalization_files = 'BL06I-EA-DET-02:CAM:EqFilePath_RBV'
#           exposure = 1.0
#             @units = 's'
#           gain_mode = 'BL06I-EA-DET-02:CAM:GainMode_RBV'
#           image_mode = 'Single'
#           image_size_x = 'Could not get data from ws128-AD-SIM-01:ArraySizeX_RBV :...'
#           image_size_y = 960
#           number_of_image = 1
#           period = 1.005
#             @units = 's'
#           region_size_x = 1280
#           region_size_y = 960
#           region_start_x = 0
#           region_start_y = 0
#           sensor_size_x = 1280
#           sensor_size_y = 960
#           threshold_energy_0 = 'BL06I-EA-DET-02:CAM:ThresholdEnergy0_RBV'
#         model = 'Basic simulator'
#       name = 'PEEM'
#       pgm:NXmonochromator
#         400llmmEnergyGradient = 0.98642902
#         400llmmEnergyReference = 248.0
#         400llmmGratingOffset = -0.056082
#         400llmmMirrorOffset = -0.02633
#         T1 = 16.0
#           @units = '°C'
#         cff = 2.25
#         energy = 800.0
#           @units = 'eV'
#         gratPitch = 0.0
#           @units = 'deg'
#         grating = 150
#           @units = 'lines/mm'
#         mirrorPitch = 0.0
#           @units = 'deg'
#       ps:NXcollection
#         phi = 0.0
#           @units = 'deg'
#         x = 0.0
#           @units = 'mm'
#         y = 0.0
#           @units = 'mm'
#       s1:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s2:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s3:NXslit
#         x_centre = 0.0
#           @units = 'mm'
#         x_gap = 0.0
#           @units = 'mm'
#         x_neg = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_centre = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_neg = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       s4:NXslit
#         x_gap = 0.0
#           @units = 'µm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'µm'
#         y_pos = 0.0
#           @units = 'mm'
#       s5:NXslit
#         x_gap = 0.0
#           @units = 'mm'
#         x_pos = 0.0
#           @units = 'mm'
#         y_gap = 0.0
#           @units = 'mm'
#         y_pos = 0.0
#           @units = 'mm'
#       source:NXsource
#         current = 250.0
#         energy = 3.0
#         name = 'Diamond Light Source'
#         probe = 'x-ray'
#         type = 'Synchrotron X-ray Source'
#       t:NXpositioner
#         @gda_scan_role = 'scannable'
#         @gda_scannable_name = 't'
#         name = 't'
#         soft_limit_max = 2000000000.0
#         soft_limit_min = -2000000000.0
#         value = float64(10)
#           @gda_field_name = 't'
#           @local_name = 't.t'
#           @target = '/entry/instrument/t/value'
#           @units = 'mm'
#       xbpm1:NXcollection
#         x = -0.0303253
#         y = 0.0489596
#       xbpm2:NXcollection
#         x = 0.213676
#         y = 0.517054
#     medipix:NXdata
#       @axes = ['t', '.', '.']
#       @signal = 'data'
#       @t_indices = 0
#       data -> medipix-23.hdf['/entry/instrument/detector/data']
#       t -> /entry/instrument/t/value
#     program_name = 'GDA 9.23.0'
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.0
#           @units = 'mm'
#         extent = 0.0
#         flux = 0.0
#         incident_beam_divergence = 0.0
#         incident_energy = 800.0
#           @units = 'eV'
#         incident_polarization = float64(4)
#     scan_command -> /entry/diamond_scan/scan_command
#     scan_shape -> /entry/diamond_scan/scan_shape
#     start_time -> /entry/diamond_scan/start_time
#     user01:NXuser
#       facility_user_id = 'fy65'
#       name = 'Fajin Yuan'

# %%
n.find('scan_command')
# Out:
# .nx.entry.diamond_scan.scan_command : 	 scan t 1 10 1 medipix 1
# .nx.entry.scan_command :

# %%
n.find('t')
# Out:
# .nx.entry.instrument.t : 	 t
# .nx.entry.medipix.t :

# %%
n.nx.plot()
# Out:
# ---------------------------------------------------------------------------
# NeXusError                                Traceback (most recent call last)
# <ipython-input-16-98590cfed531> in <module>
# ----> 1 n.nx.plot()
#
# ~/.local/lib/python3.7/site-packages/nexusformat/nexus/tree.py in plot(self, **kwargs)
#    4882         plotdata = self.plottable_data
#    4883         if plotdata:
# -> 4884             plotdata.plot(**kwargs)
#    4885         else:
#    4886             raise NeXusError("There is no plottable data")
#
# ~/.local/lib/python3.7/site-packages/nexusformat/nexus/tree.py in plot(self, fmt, xmin, xmax, ymin, ymax, vmin, vmax, **kwargs)
#    6364             raise NeXusError("No plotting signal defined")
#    6365         elif not signal.exists():
# -> 6366             raise NeXusError("Data for '%s' does not exist" % signal.nxpath)
#    6367         elif not signal.is_plottable():
#    6368             raise NeXusError("'%s' is not plottable" % signal.nxpath)
#
# NeXusError: Data for '/entry/medipix/data' does not exist
